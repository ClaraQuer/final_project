# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from sklearn.metrics import r2_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.preprocessing import OneHotEncoder

# %%
pd.set_option('display.max_columns', 155, 'display.max_rows', 1000)

# %% [markdown]
# ### Getting all the data imported

# %%
data1 = pd.read_csv('..\Data\jetpack1.csv')
# Out:
# C:\Users\herat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,12,15,18,27,30,33,42,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data2 = pd.read_csv('..\Data\jetpack2.csv')

# %%
data3 = pd.read_csv('..\Data\jetpack3.csv')

# %% [markdown]
# ### Concatenating dfs

# %%
data = pd.concat([data1, data2, data3], axis = 0)

# %%
data.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data.head()
# Out:
#    user_pseudo_id  m1_mission_completed m1_mission_id  m1_mission_difficulty  \
# 0        15725157                   3.0     Mission94                    2.0
# 1        85942635                   3.0    Mission113                    1.0
# 2        23900985                   3.0    Mission109                    1.0
# 3        58130048                   3.0     Mission94                    2.0
# 4        65693590                   3.0    Mission115                    1.0
#
#    m1_mission_stars_collected  m1_day_auto_increment  m1_lifetime_played_runs  \
# 0                         3.0                    0.0                      2.0
# 1                         3.0                    0.0                      1.0
# 2                         3.0                    1.0                      2.0
# 3                         1.0                    1.0                      2.0
# 4                         3.0                    0.0                      1.0
#
#    m1_max_run_distance  m1_total_purchases_virtual  m1_total_ads_watched  \
# 0               1763.0                      2000.0                   0.0
# 1               1653.0                         0.0                   0.0
# 2               1203.0                         0.0                   0.0
# 3               1046.0                      1000.0                   0.0
# 4               1250.0                         0.0                   0.0
#
#    m1_total_purchases_real m1_geo_country  m1_days_played_in_month  \
# 0                      0.0       Honduras                      0.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      1.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      0.0
#
#    m1_virtual_currency_balance           m1_event_timestamp  user_pseudo_id_1  \
# 0                       5000.0  2022-03-02 15:46:04.025 UTC          15725157
# 1                       5644.0  2022-02-04 21:16:01.131 UTC          85942635
# 2                       5285.0  2022-02-19 04:23:19.464 UTC          23900985
# 3                       4343.0  2022-02-25 04:49:05.706 UTC          58130048
# 4                       5482.0  2022-02-14 15:37:03.106 UTC          65693590
#
#    m2_mission_completed m2_mission_id  m2_mission_difficulty  \
# 0                   4.0    Mission109                    1.0
# 1                   4.0    Mission109                    1.0
# 2                   4.0    Mission113                    1.0
# 3                   4.0    Mission115                    1.0
# 4                   4.0    Mission113                    1.0
#
#    m2_mission_stars_collected  m2_day_auto_increment  m2_lifetime_played_runs  \
# 0                         4.0                    0.0                      3.0
# 1                         3.0                    0.0                      1.0
# 2                         3.0                    1.0                      2.0
# 3                         1.0                    1.0                      2.0
# 4                         4.0                    0.0                      2.0
#
#    m2_max_run_distance  m2_total_purchases_virtual  m2_total_ads_watched  \
# 0               2266.0                      2000.0                   0.0
# 1               1653.0                         0.0                   0.0
# 2               1203.0                         0.0                   0.0
# 3               1046.0                      1000.0                   0.0
# 4               1486.0                         0.0                   0.0
#
#    m2_total_purchases_real m2_geo_country  m2_days_played_in_month  \
# 0                      0.0       Honduras                      0.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      1.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      0.0
#
#    m2_virtual_currency_balance           m2_event_timestamp  user_pseudo_id_2  \
# 0                       4238.0  2022-03-02 15:46:51.889 UTC          15725157
# 1                       5644.0  2022-02-04 21:16:02.086 UTC          85942635
# 2                       5285.0   2022-02-19 04:23:20.96 UTC          23900985
# 3                       4343.0  2022-02-25 04:49:13.325 UTC          58130048
# 4                       5599.0  2022-02-14 15:38:39.378 UTC          65693590
#
#    m3_mission_completed m3_mission_id  m3_mission_difficulty  \
# 0                   5.0    Mission115                    1.0
# 1                   5.0    Mission115                    1.0
# 2                   5.0    Mission115                    1.0
# 3                   5.0    Mission109                    1.0
# 4                   5.0    Mission109                    1.0
#
#    m3_mission_stars_collected  m3_day_auto_increment  m3_lifetime_played_runs  \
# 0                         5.0                    0.0                      8.0
# 1                         3.0                    0.0                      1.0
# 2                         5.0                    1.0                      3.0
# 3                         5.0                    1.0                     11.0
# 4                         5.0                    1.0                      3.0
#
#    m3_max_run_distance  m3_total_purchases_virtual  m3_total_ads_watched  \
# 0               2266.0                      3500.0                   0.0
# 1               1653.0                         0.0                   0.0
# 2               1346.0                         0.0                   1.0
# 3               1046.0                      5500.0                   0.0
# 4               1486.0                         0.0                   0.0
#
#    m3_total_purchases_real m3_geo_country  m3_days_played_in_month  \
# 0                      0.0       Honduras                      0.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      1.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      1.0
#
#    m3_virtual_currency_balance           m3_event_timestamp  user_pseudo_id_3  \
# 0                       3561.0  2022-03-02 15:54:49.526 UTC          15725157
# 1                       5644.0   2022-02-04 21:16:17.07 UTC          85942635
# 2                       5323.0  2022-02-19 04:25:50.388 UTC          23900985
# 3                        389.0  2022-02-25 09:08:26.902 UTC          58130048
# 4                       5639.0  2022-02-14 20:45:14.263 UTC          65693590
#
#    m4_mission_completed m4_mission_id  m4_mission_difficulty  \
# 0                   6.0    Mission114                    1.0
# 1                   6.0      Mission3                    1.0
# 2                   6.0     Mission11                    1.0
# 3                   6.0      Mission3                    1.0
# 4                   6.0    Mission114                    1.0
#
#    m4_mission_stars_collected  m4_day_auto_increment  m4_lifetime_played_runs  \
# 0                         6.0                    2.0                      9.0
# 1                         6.0                    0.0                      2.0
# 2                         5.0                    1.0                      3.0
# 3                         6.0                    1.0                     12.0
# 4                         6.0                    1.0                      6.0
#
#    m4_max_run_distance  m4_total_purchases_virtual  m4_total_ads_watched  \
# 0               2266.0                      3500.0                   0.0
# 1               3790.0                         0.0                   0.0
# 2               1346.0                         0.0                   1.0
# 3               1046.0                      5500.0                   0.0
# 4               1486.0                      1500.0                   0.0
#
#    m4_total_purchases_real m4_geo_country  m4_days_played_in_month  \
# 0                      0.0       Honduras                      2.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      1.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      1.0
#
#    m4_virtual_currency_balance           m4_event_timestamp  user_pseudo_id_4  \
# 0                       4284.0  2022-03-05 17:52:48.383 UTC          15725157
# 1                       6541.0  2022-02-04 21:18:18.761 UTC          85942635
# 2                       5323.0  2022-02-19 04:26:26.774 UTC          23900985
# 3                        916.0  2022-02-25 09:10:18.692 UTC          58130048
# 4                       5182.0  2022-02-15 05:31:38.882 UTC          65693590
#
#    m5_mission_completed m5_mission_id  m5_mission_difficulty  \
# 0                   7.0      Mission3                    1.0
# 1                   7.0    Mission114                    1.0
# 2                   7.0      Mission3                    1.0
# 3                   7.0    Mission114                    1.0
# 4                   7.0      Mission3                    1.0
#
#    m5_mission_stars_collected  m5_day_auto_increment  m5_lifetime_played_runs  \
# 0                         7.0                    2.0                     12.0
# 1                         6.0                    0.0                      2.0
# 2                         7.0                    1.0                      4.0
# 3                         6.0                    1.0                     12.0
# 4                         7.0                    1.0                      7.0
#
#    m5_max_run_distance  m5_total_purchases_virtual  m5_total_ads_watched  \
# 0               2266.0                      7000.0                   0.0
# 1               3790.0                         0.0                   0.0
# 2               1346.0                      1000.0                   2.0
# 3               1046.0                      5500.0                   0.0
# 4               2538.0                      1500.0                   0.0
#
#    m5_total_purchases_real m5_geo_country  m5_days_played_in_month  \
# 0                      0.0       Honduras                      2.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      1.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      1.0
#
#    m5_virtual_currency_balance           m5_event_timestamp  user_pseudo_id_5  \
# 0                       1306.0  2022-03-05 17:56:06.473 UTC          15725157
# 1                       6541.0  2022-02-04 21:18:26.108 UTC          85942635
# 2                       4698.0  2022-02-19 04:28:54.582 UTC          23900985
# 3                        916.0  2022-02-25 09:10:19.547 UTC          58130048
# 4                       6939.0  2022-02-15 05:34:37.177 UTC          65693590
#
#    m6_mission_completed m6_mission_id  m6_mission_difficulty  \
# 0                   8.0     Mission11                    1.0
# 1                   8.0      Mission3                    1.0
# 2                   8.0      Mission6                    1.0
# 3                   8.0     Mission11                    1.0
# 4                   8.0     Mission11                    1.0
#
#    m6_mission_stars_collected  m6_day_auto_increment  m6_lifetime_played_runs  \
# 0                         8.0                    3.0                     19.0
# 1                         8.0                    0.0                      3.0
# 2                         7.0                    1.0                      4.0
# 3                         6.0                    1.0                     12.0
# 4                         8.0                    1.0                     11.0
#
#    m6_max_run_distance  m6_total_purchases_virtual  m6_total_ads_watched  \
# 0               2585.0                      7000.0                   0.0
# 1               3790.0                         0.0                   1.0
# 2               1346.0                      1000.0                   2.0
# 3               1046.0                      5500.0                   0.0
# 4               2538.0                      1500.0                   0.0
#
#    m6_total_purchases_real m6_geo_country  m6_days_played_in_month  \
# 0                      0.0       Honduras                      3.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      1.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      1.0
#
#    m6_virtual_currency_balance           m6_event_timestamp  user_pseudo_id_6  \
# 0                       2446.0  2022-03-14 02:00:06.716 UTC          15725157
# 1                       7499.0  2022-02-04 21:22:22.796 UTC          85942635
# 2                       4698.0  2022-02-19 04:29:17.305 UTC          23900985
# 3                        916.0  2022-02-25 09:10:24.558 UTC          58130048
# 4                       7657.0  2022-02-15 14:54:06.978 UTC          65693590
#
#    m7_mission_completed m7_mission_id  m7_mission_difficulty  \
# 0                   9.0     Mission19                    2.0
# 1                   9.0     Mission19                    2.0
# 2                   9.0     Mission19                    2.0
# 3                   9.0     Mission19                    2.0
# 4                   9.0     Mission19                    2.0
#
#    m7_mission_stars_collected  m7_day_auto_increment  m7_lifetime_played_runs  \
# 0                         8.0                    3.0                     19.0
# 1                         9.0                    0.0                      3.0
# 2                         9.0                    1.0                      5.0
# 3                         9.0                    1.0                     13.0
# 4                         9.0                    1.0                     17.0
#
#    m7_max_run_distance  m7_total_purchases_virtual  m7_total_ads_watched  \
# 0               2585.0                      7000.0                   0.0
# 1               3790.0                         0.0                   1.0
# 2               3581.0                      1000.0                   3.0
# 3               2261.0                      5500.0                   0.0
# 4               2538.0                      1500.0                   0.0
#
#    m7_total_purchases_real m7_geo_country  m7_days_played_in_month  \
# 0                      0.0       Honduras                      3.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      1.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      1.0
#
#    m7_virtual_currency_balance           m8_event_timestamp  user_pseudo_id_7  \
# 0                       2446.0  2022-03-14 02:00:19.959 UTC          15725157
# 1                       7499.0  2022-02-04 21:22:30.976 UTC          85942635
# 2                       6145.0  2022-02-19 04:33:45.547 UTC          23900985
# 3                       1691.0    2022-02-25 09:13:24.8 UTC          58130048
# 4                       8842.0  2022-02-15 15:03:07.339 UTC          65693590
#
#    m8_mission_completed m8_mission_id  m8_mission_difficulty  \
# 0                  10.0      Mission6                    1.0
# 1                  10.0     Mission86                    2.0
# 2                  10.0     Mission86                    2.0
# 3                  10.0     Mission12                    2.0
# 4                  10.0     Mission86                    2.0
#
#    m8_mission_stars_collected  m8_day_auto_increment  m8_lifetime_played_runs  \
# 0                        11.0                    3.0                     20.0
# 1                        11.0                    0.0                      4.0
# 2                        11.0                    1.0                      7.0
# 3                        11.0                    1.0                     14.0
# 4                        11.0                    1.0                     18.0
#
#    m8_max_run_distance  m8_total_purchases_virtual  m8_total_ads_watched  \
# 0               2585.0                      7000.0                   0.0
# 1               3790.0                         0.0                   2.0
# 2               3581.0                      1000.0                   4.0
# 3               2261.0                      5500.0                   0.0
# 4               2538.0                      1500.0                   0.0
#
#    m8_total_purchases_real m8_geo_country  m8_days_played_in_month  \
# 0                      0.0       Honduras                      3.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      1.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      1.0
#
#    m8_virtual_currency_balance         m8_event_timestamp_1  user_pseudo_id_8  \
# 0                       2752.0  2022-03-14 02:01:13.236 UTC          15725157
# 1                       9379.0  2022-02-04 21:24:52.568 UTC          85942635
# 2                       7669.0  2022-02-19 04:39:52.859 UTC          23900985
# 3                       2037.0  2022-02-25 09:14:40.943 UTC          58130048
# 4                       8972.0  2022-02-15 15:04:46.376 UTC          65693590
#
#    m9_mission_completed m9_mission_id  m9_mission_difficulty  \
# 0                  11.0     Mission86                    2.0
# 1                  11.0     Mission19                    2.0
# 2                  11.0     Mission12                    2.0
# 3                  11.0     Mission86                    2.0
# 4                  11.0     Mission12                    2.0
#
#    m9_mission_stars_collected  m9_day_auto_increment  m9_lifetime_played_runs  \
# 0                        12.0                    3.0                     21.0
# 1                        11.0                    0.0                      4.0
# 2                        13.0                    2.0                     12.0
# 3                        13.0                    1.0                     15.0
# 4                        13.0                    1.0                     26.0
#
#    m9_max_run_distance  m9_total_purchases_virtual  m9_total_ads_watched  \
# 0               2585.0                      7000.0                   0.0
# 1               3790.0                         0.0                   2.0
# 2               3581.0                      1000.0                   8.0
# 3               2261.0                      5500.0                   0.0
# 4               2538.0                      1500.0                   0.0
#
#    m9_total_purchases_real m9_geo_country  m9_days_played_in_month  \
# 0                      0.0       Honduras                      3.0
# 1                      0.0        Belgium                      0.0
# 2                      0.0        Vietnam                      2.0
# 3                      0.0         Taiwan                      1.0
# 4                      0.0     Bangladesh                      1.0
#
#    m9_virtual_currency_balance           m9_event_timestamp  user_pseudo_id_9  \
# 0                       3322.0  2022-03-14 02:03:20.305 UTC          15725157
# 1                       9379.0  2022-02-04 21:25:05.659 UTC          85942635
# 2                       8657.0  2022-02-20 03:44:26.355 UTC          23900985
# 3                       2055.0  2022-02-25 09:16:37.834 UTC          58130048
# 4                      11848.0  2022-02-15 17:08:28.601 UTC          65693590
#
#    m10_mission_completed m10_mission_id  m10_mission_difficulty  \
# 0                     12      Mission12                       2
# 1                     12      Mission86                       2
# 2                     12     Mission114                       1
# 3                     12      Mission10                       1
# 4                     12       Mission6                       1
#
#    m10_mission_stars_collected  m10_day_auto_increment  \
# 0                           14                     3.0
# 1                           15                     0.0
# 2                           15                     2.0
# 3                           15                     2.0
# 4                           15                     1.0
#
#    m10_lifetime_played_runs  m10_max_run_distance  \
# 0                      23.0                2585.0
# 1                       5.0                3790.0
# 2                      14.0                3581.0
# 3                      24.0                3314.0
# 4                      29.0                2538.0
#
#    m10_total_purchases_virtual  m10_total_ads_watched  \
# 0                       8500.0                    0.0
# 1                          0.0                    3.0
# 2                      10000.0                   10.0
# 3                       5500.0                    0.0
# 4                      11500.0                    0.0
#
#    m10_total_purchases_real m10_geo_country  m10_days_played_in_month  \
# 0                       0.0        Honduras                       3.0
# 1                       0.0         Belgium                       0.0
# 2                       0.0         Vietnam                       2.0
# 3                       0.0          Taiwan                       0.0
# 4                       0.0      Bangladesh                       1.0
#
#    m10_virtual_currency_balance          m10_event_timestamp  \
# 0                        2820.0  2022-03-14 02:05:01.562 UTC
# 1                       10179.0  2022-02-04 21:26:53.862 UTC
# 2                          57.0  2022-02-20 03:50:41.292 UTC
# 3                        6634.0  2022-03-02 09:22:12.536 UTC
# 4                        3577.0  2022-02-15 17:16:44.864 UTC
#
#    user_pseudo_id_10  target_max_day_played
# 0           15725157                      4
# 1           85942635                      4
# 2           23900985                      2
# 3           58130048                      2
# 4           65693590                      5

# %% [markdown]
# ### Cleaning data

# %%
data[data.duplicated()]
# Out:
#    user_pseudo_id  m1_mission_completed m1_mission_id  m1_mission_difficulty  \
# 0         2683761                   3.0    Mission115                    1.0
# 0        59165161                   3.0    Mission115                    1.0
#
#    m1_mission_stars_collected  m1_day_auto_increment  m1_lifetime_played_runs  \
# 0                         3.0                    0.0                      1.0
# 0                         3.0                    0.0                      1.0
#
#    m1_max_run_distance  m1_total_purchases_virtual  m1_total_ads_watched  \
# 0               3298.0                         0.0                   0.0
# 0               1065.0                         0.0                   0.0
#
#    m1_total_purchases_real m1_geo_country  m1_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m1_virtual_currency_balance           m1_event_timestamp  user_pseudo_id_1  \
# 0                       5745.0  2022-02-13 19:51:48.694 UTC           2683761
# 0                       5539.0  2022-02-11 11:36:12.017 UTC          59165161
#
#    m2_mission_completed m2_mission_id  m2_mission_difficulty  \
# 0                   4.0    Mission113                    1.0
# 0                   4.0    Mission113                    1.0
#
#    m2_mission_stars_collected  m2_day_auto_increment  m2_lifetime_played_runs  \
# 0                         3.0                    0.0                      1.0
# 0                         3.0                    0.0                      1.0
#
#    m2_max_run_distance  m2_total_purchases_virtual  m2_total_ads_watched  \
# 0               3298.0                         0.0                   0.0
# 0               1065.0                         0.0                   0.0
#
#    m2_total_purchases_real m2_geo_country  m2_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m2_virtual_currency_balance           m2_event_timestamp  user_pseudo_id_2  \
# 0                       5745.0  2022-02-13 19:52:23.665 UTC           2683761
# 0                       5539.0  2022-02-11 11:36:37.736 UTC          59165161
#
#    m3_mission_completed m3_mission_id  m3_mission_difficulty  \
# 0                   5.0    Mission109                    1.0
# 0                   5.0    Mission109                    1.0
#
#    m3_mission_stars_collected  m3_day_auto_increment  m3_lifetime_played_runs  \
# 0                         3.0                    0.0                      1.0
# 0                         3.0                    0.0                      1.0
#
#    m3_max_run_distance  m3_total_purchases_virtual  m3_total_ads_watched  \
# 0               3298.0                         0.0                   0.0
# 0               1065.0                         0.0                   0.0
#
#    m3_total_purchases_real m3_geo_country  m3_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m3_virtual_currency_balance           m3_event_timestamp  user_pseudo_id_3  \
# 0                       5745.0  2022-02-13 19:52:28.163 UTC           2683761
# 0                       5539.0  2022-02-11 11:36:40.707 UTC          59165161
#
#    m4_mission_completed m4_mission_id  m4_mission_difficulty  \
# 0                   6.0    Mission114                    1.0
# 0                   6.0     Mission11                    1.0
#
#    m4_mission_stars_collected  m4_day_auto_increment  m4_lifetime_played_runs  \
# 0                         6.0                    0.0                      2.0
# 0                         6.0                    0.0                      3.0
#
#    m4_max_run_distance  m4_total_purchases_virtual  m4_total_ads_watched  \
# 0               3298.0                         0.0                   0.0
# 0               1328.0                         0.0                   0.0
#
#    m4_total_purchases_real m4_geo_country  m4_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m4_virtual_currency_balance           m4_event_timestamp  user_pseudo_id_4  \
# 0                       6346.0  2022-02-13 21:33:40.621 UTC           2683761
# 0                       6314.0  2022-02-11 11:39:15.276 UTC          59165161
#
#    m5_mission_completed m5_mission_id  m5_mission_difficulty  \
# 0                   7.0      Mission3                    1.0
# 0                   7.0      Mission6                    1.0
#
#    m5_mission_stars_collected  m5_day_auto_increment  m5_lifetime_played_runs  \
# 0                         7.0                    0.0                      3.0
# 0                         7.0                    0.0                      6.0
#
#    m5_max_run_distance  m5_total_purchases_virtual  m5_total_ads_watched  \
# 0               3298.0                         0.0                   1.0
# 0               1700.0                         0.0                   0.0
#
#    m5_total_purchases_real m5_geo_country  m5_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m5_virtual_currency_balance           m5_event_timestamp  user_pseudo_id_5  \
# 0                       8643.0  2022-02-14 01:22:16.965 UTC           2683761
# 0                       7857.0  2022-02-11 11:49:44.198 UTC          59165161
#
#    m6_mission_completed m6_mission_id  m6_mission_difficulty  \
# 0                   8.0     Mission11                    1.0
# 0                   8.0    Mission114                    1.0
#
#    m6_mission_stars_collected  m6_day_auto_increment  m6_lifetime_played_runs  \
# 0                         7.0                    0.0                      3.0
# 0                         8.0                    0.0                      7.0
#
#    m6_max_run_distance  m6_total_purchases_virtual  m6_total_ads_watched  \
# 0               3298.0                         0.0                   1.0
# 0               1700.0                         0.0                   0.0
#
#    m6_total_purchases_real m6_geo_country  m6_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m6_virtual_currency_balance           m6_event_timestamp  user_pseudo_id_6  \
# 0                       8643.0  2022-02-14 01:22:19.842 UTC           2683761
# 0                       7565.0  2022-02-11 11:50:11.498 UTC          59165161
#
#    m7_mission_completed m7_mission_id  m7_mission_difficulty  \
# 0                   9.0      Mission6                    1.0
# 0                   9.0     Mission19                    2.0
#
#    m7_mission_stars_collected  m7_day_auto_increment  m7_lifetime_played_runs  \
# 0                         9.0                    0.0                      4.0
# 0                         9.0                    0.0                      7.0
#
#    m7_max_run_distance  m7_total_purchases_virtual  m7_total_ads_watched  \
# 0               3298.0                         0.0                   2.0
# 0               1700.0                         0.0                   0.0
#
#    m7_total_purchases_real m7_geo_country  m7_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m7_virtual_currency_balance           m8_event_timestamp  user_pseudo_id_7  \
# 0                      10715.0  2022-02-14 01:24:00.226 UTC           2683761
# 0                       7165.0  2022-02-11 11:50:20.675 UTC          59165161
#
#    m8_mission_completed m8_mission_id  m8_mission_difficulty  \
# 0                  10.0     Mission86                    2.0
# 0                  10.0      Mission3                    1.0
#
#    m8_mission_stars_collected  m8_day_auto_increment  m8_lifetime_played_runs  \
# 0                        10.0                    0.0                      5.0
# 0                        11.0                    0.0                      7.0
#
#    m8_max_run_distance  m8_total_purchases_virtual  m8_total_ads_watched  \
# 0               3298.0                         0.0                   3.0
# 0               1700.0                         0.0                   0.0
#
#    m8_total_purchases_real m8_geo_country  m8_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m8_virtual_currency_balance         m8_event_timestamp_1  user_pseudo_id_8  \
# 0                      11020.0  2022-02-14 01:26:24.478 UTC           2683761
# 0                       6665.0  2022-02-11 11:50:23.685 UTC          59165161
#
#    m9_mission_completed m9_mission_id  m9_mission_difficulty  \
# 0                  11.0     Mission19                    2.0
# 0                  11.0     Mission12                    2.0
#
#    m9_mission_stars_collected  m9_day_auto_increment  m9_lifetime_played_runs  \
# 0                        10.0                    0.0                      5.0
# 0                        12.0                    0.0                      7.0
#
#    m9_max_run_distance  m9_total_purchases_virtual  m9_total_ads_watched  \
# 0               3298.0                         0.0                   3.0
# 0               1700.0                         0.0                   0.0
#
#    m9_total_purchases_real m9_geo_country  m9_days_played_in_month  \
# 0                      0.0         Brazil                      0.0
# 0                      0.0        Nigeria                      0.0
#
#    m9_virtual_currency_balance           m9_event_timestamp  user_pseudo_id_9  \
# 0                      11020.0  2022-02-14 01:26:47.376 UTC           2683761
# 0                       5665.0   2022-02-11 11:50:27.89 UTC          59165161
#
#    m10_mission_completed m10_mission_id  m10_mission_difficulty  \
# 0                     12      Mission12                       2
# 0                     12      Mission86                       2
#
#    m10_mission_stars_collected  m10_day_auto_increment  \
# 0                           14                     0.0
# 0                           14                     0.0
#
#    m10_lifetime_played_runs  m10_max_run_distance  \
# 0                       9.0                3298.0
# 0                       7.0                1700.0
#
#    m10_total_purchases_virtual  m10_total_ads_watched  \
# 0                      15000.0                    7.0
# 0                          0.0                    0.0
#
#    m10_total_purchases_real m10_geo_country  m10_days_played_in_month  \
# 0                       0.0          Brazil                       0.0
# 0                       0.0         Nigeria                       0.0
#
#    m10_virtual_currency_balance          m10_event_timestamp  \
# 0                        3521.0  2022-02-14 01:37:47.616 UTC
# 0                        5465.0  2022-02-11 11:50:37.468 UTC
#
#    user_pseudo_id_10  target_max_day_played
# 0            2683761                      0
# 0           59165161                      1

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# ### Checking id column

# %%
ids = data['user_pseudo_id'].value_counts()
ids = pd.DataFrame(ids).reset_index()
ids.columns = ['id', 'count']
ids.sort_values(by = 'count', ascending = False)
# Out:
#               id  count
# 0       72706784  19853
# 1       70089430      3
# 248     27601698      2
# 257     71760342      2
# 256     81679514      2
# ...          ...    ...
# 90244   39281465      1
# 90245   64889173      1
# 90246   81725463      1
# 90247   63295335      1
# 269971  57543559      1
#
# [269972 rows x 2 columns]

# %%
len(ids[ids['count'] > 1]) #There's 376 repeted ids with at least 2 reptetitions, so I'm not going to be using this column.
# Out:
# 376

# %% [markdown]
# ### Aggregating targets

# %%
cols = list(data.columns)

# %%
real_purchases = []
virtual_purchases = []
ads = []

for i in cols:
    if 'total_purchases_real' in i:
        real_purchases.append(i)
    elif 'total_purchases_virtual' in i:
        virtual_purchases.append(i)
    elif 'total_ads' in i:
        ads.append(i)

# %%
data['real_purchases_sum'] = data[real_purchases].sum(1)
data['virtual_purchases_sum'] = data[virtual_purchases].sum(1)
data['ads_sum'] = data[ads].sum(1)

# %%
total_targets = data[['real_purchases_sum', 'virtual_purchases_sum', 'ads_sum']]

# %% [markdown]
# ### Cleaning mission_id columns:

# %%
for i in cols:
    if 'mission_id' in i:        
        data[i] = data[i].astype('string')
        data[i] = data[i].str.replace('Mission', '')
        data[i] = pd.to_numeric(data[i], errors='coerce')

# %%
data
# Out:
#        user_pseudo_id  m1_mission_completed  m1_mission_id  \
# 0            15725157                   3.0           94.0
# 1            85942635                   3.0          113.0
# 2            23900985                   3.0          109.0
# 3            58130048                   3.0           94.0
# 4            65693590                   3.0          115.0
# ...               ...                   ...            ...
# 96729        60821427                   3.0          113.0
# 96730         6627955                   3.0          115.0
# 96731        30584741                   3.0          115.0
# 96732        62949474                   3.0          113.0
# 96733        57543559                   3.0          115.0
#
#        m1_mission_difficulty  m1_mission_stars_collected  \
# 0                        2.0                         3.0
# 1                        1.0                         3.0
# 2                        1.0                         3.0
# 3                        2.0                         1.0
# 4                        1.0                         3.0
# ...                      ...                         ...
# 96729                    1.0                         1.0
# 96730                    1.0                         3.0
# 96731                    1.0                         3.0
# 96732                    1.0                         3.0
# 96733                    1.0                         3.0
#
#        m1_day_auto_increment  m1_lifetime_played_runs  m1_max_run_distance  \
# 0                        0.0                      2.0               1763.0
# 1                        0.0                      1.0               1653.0
# 2                        1.0                      2.0               1203.0
# 3                        1.0                      2.0               1046.0
# 4                        0.0                      1.0               1250.0
# ...                      ...                      ...                  ...
# 96729                    0.0                      1.0               1373.0
# 96730                    0.0                      1.0               3046.0
# 96731                    0.0                      1.0               1019.0
# 96732                    0.0                      1.0               2206.0
# 96733                    0.0                      1.0               1380.0
#
#        m1_total_purchases_virtual  m1_total_ads_watched  \
# 0                          2000.0                   0.0
# 1                             0.0                   0.0
# 2                             0.0                   0.0
# 3                          1000.0                   0.0
# 4                             0.0                   0.0
# ...                           ...                   ...
# 96729                      1500.0                   0.0
# 96730                         0.0                   0.0
# 96731                      3000.0                   0.0
# 96732                      5000.0                   0.0
# 96733                         0.0                   0.0
#
#        m1_total_purchases_real  m1_geo_country  m1_days_played_in_month  \
# 0                          0.0        Honduras                      0.0
# 1                          0.0         Belgium                      0.0
# 2                          0.0         Vietnam                      1.0
# 3                          0.0          Taiwan                      1.0
# 4                          0.0      Bangladesh                      0.0
# ...                        ...             ...                      ...
# 96729                      0.0  United Kingdom                      0.0
# 96730                      0.0  United Kingdom                      0.0
# 96731                      0.0  United Kingdom                      0.0
# 96732                      0.0  United Kingdom                      0.0
# 96733                      0.0  United Kingdom                      0.0
#
#        m1_virtual_currency_balance           m1_event_timestamp  \
# 0                           5000.0  2022-03-02 15:46:04.025 UTC
# 1                           5644.0  2022-02-04 21:16:01.131 UTC
# 96730                     1.0                       9.0                4082.0
# 96731                     2.0                      24.0                3326.0
# 96732                     0.0                      15.0                3485.0
# 96733                     2.0                      21.0                4662.0
#
#        m10_total_purchases_virtual  m10_total_ads_watched  \
# 0                           8500.0                    0.0
# 1                              0.0                    3.0
# 2                          10000.0                   10.0
# 3                           5500.0                    0.0
# 4                          11500.0                    0.0
# ...                            ...                    ...
# 96729                       5500.0                    4.0
# 96730                       4000.0                    6.0
# 96731                      12000.0                    1.0
# 96732                       7000.0                    0.0
# 96733                      21000.0                   22.0
#
#        m10_total_purchases_real m10_geo_country  m10_days_played_in_month  \
# 0                           0.0        Honduras                       3.0
# 1                           0.0         Belgium                       0.0
# 2                           0.0         Vietnam                       2.0
# 3                           0.0          Taiwan                       0.0
# 4                           0.0      Bangladesh                       1.0
# ...                         ...             ...                       ...
# 96729                       0.0  United Kingdom                       0.0
# 96730                       0.0  United Kingdom                       1.0
# 96731                       0.0  United Kingdom                       2.0
# 96732                       0.0  United Kingdom                       0.0
# 96733                       0.0  United Kingdom                       2.0
#
#        m10_virtual_currency_balance          m10_event_timestamp  \
# 0                            2820.0  2022-03-14 02:05:01.562 UTC
# 1                           10179.0  2022-02-04 21:26:53.862 UTC
# 2                              57.0  2022-02-20 03:50:41.292 UTC
# 3                            6634.0  2022-03-02 09:22:12.536 UTC
# 4                            3577.0  2022-02-15 17:16:44.864 UTC
# ...                             ...                          ...
# 96729                        2624.0  2022-02-21 20:23:16.173 UTC
# 96730                       10031.0  2022-02-14 13:50:39.238 UTC
# 96731                        3141.0  2022-02-14 19:14:50.712 UTC
# 96732                        2270.0  2022-02-01 10:00:33.435 UTC
# 96733                        2628.0  2022-02-13 14:49:04.674 UTC
#
#        user_pseudo_id_10  target_max_day_played  real_purchases_sum  \
# 0               15725157                      4                 0.0
# 1               85942635                      4                 0.0
# 2               23900985                      2                 0.0
# 3               58130048                      2                 0.0
# 4               65693590                      5                 0.0
# ...                  ...                    ...                 ...
# 96729           60821427                      9                 0.0
# 96730            6627955                     13                 0.0
# 96731           30584741                      3                 0.0
# 96732           62949474                      4                 0.0
# 96733           57543559                      5                 0.0
#
#        virtual_purchases_sum  ads_sum
# 0                    54500.0      0.0
# 1                        0.0      9.0
# 2                    15000.0     31.0
# 3                    46000.0      0.0
# 4                    20500.0      0.0
# ...                      ...      ...
# 96729                19000.0     20.0
# 96730                16000.0     25.0
# 96731                68000.0      7.0
# 96732                58000.0      0.0
# 96733                59500.0     70.0
#
# [290200 rows x 155 columns]

# %% [markdown]
# ### Percentages of the total for each target

# %%
len(data[data['real_purchases_sum'] != 0])/(len(data))*100
# Out:
# 1.116471399035148

# %%
len(data[data['virtual_purchases_sum'] != 0])/(len(data))*100
# Out:
# 73.32804962095106

# %%
len(data[data['ads_sum'] != 0])/(len(data))*100
# Out:
# 72.9552033080634

# %% [markdown]
# ### Checkin NaNs

# %%
nas = data.isna().sum()

# %%
nas = pd.DataFrame(nas, columns = ['na'])
nas
# Out:
#                                  na
# user_pseudo_id                    0
# m1_mission_completed          19853
# m1_mission_id                 20294
# m1_mission_difficulty         19853
# m1_mission_stars_collected    19853
# m1_day_auto_increment         19854
# m1_lifetime_played_runs       20658
# m1_max_run_distance           20658
# m1_total_purchases_virtual    20675
# m1_total_ads_watched          20680
# m1_total_purchases_real       20680
# m1_geo_country                19995
# m1_days_played_in_month       20659
# m1_virtual_currency_balance   20658
# m1_event_timestamp            19853
# user_pseudo_id_1                  0
# m2_mission_completed          19044
# m2_mission_id                 19412
# m2_mission_difficulty         19044
# m2_mission_stars_collected    19044
# m2_day_auto_increment         19045
# m2_lifetime_played_runs       19857
# m2_max_run_distance           19857
# m2_total_purchases_virtual    19870
# m2_total_ads_watched          19877
# m2_total_purchases_real       19877
# m2_geo_country                19204
# m2_days_played_in_month       19858
# m2_virtual_currency_balance   19857
# m2_event_timestamp            19044
# user_pseudo_id_2                  0
# m3_mission_completed          18156
# m3_mission_id                 18514
# m3_mission_difficulty         18156
# m3_mission_stars_collected    18156
# m3_day_auto_increment         18157
# m3_lifetime_played_runs       18975
# m3_max_run_distance           18975
# m3_total_purchases_virtual    18987
# m3_total_ads_watched          18993
# m3_total_purchases_real       18995
# m3_geo_country                18338
# m3_days_played_in_month       18976
# m3_virtual_currency_balance   18975
# m3_event_timestamp            18156
# user_pseudo_id_3                  0
# m4_mission_completed          16653
# m4_mission_id                 16961
# m4_mission_difficulty         16653
# m4_mission_stars_collected    16653
# m4_day_auto_increment         16656
# m4_lifetime_played_runs       17489
# m4_max_run_distance           17489
# m4_total_purchases_virtual    17500
# m4_total_ads_watched          17501
# m4_total_purchases_real       17506
# m4_geo_country                16874
# m4_days_played_in_month       17490
# m4_virtual_currency_balance   17489
# m4_event_timestamp            16653
# user_pseudo_id_4                  0
# m5_mission_completed          15171
# m5_mission_id                 15453
# m5_mission_difficulty         15171
# m5_mission_stars_collected    15171
# m5_day_auto_increment         15174
# m5_lifetime_played_runs       16013
# m5_max_run_distance           16014
# m5_total_purchases_virtual    16025
# m5_total_ads_watched          16022
# m5_total_purchases_real       16030
# m5_geo_country                15438
# m5_days_played_in_month       16015
# m5_virtual_currency_balance   16013
# m5_event_timestamp            15171
# user_pseudo_id_5                  0
# m6_mission_completed          13386
# m6_mission_id                 13657
# m6_mission_difficulty         13386
# m6_mission_stars_collected    13386
# m6_day_auto_increment         13388
# m6_lifetime_played_runs       14232
# m6_max_run_distance           14233
# m6_total_purchases_virtual    14242
# m6_total_ads_watched          14237
# m6_total_purchases_real       14247
# m6_geo_country                13710
# m6_days_played_in_month       14234
# m6_virtual_currency_balance   14232
# m6_event_timestamp            13386
# user_pseudo_id_6                  0
# m7_mission_completed          11269
# m7_mission_id                 11561
# m7_mission_difficulty         11269
# m7_mission_stars_collected    11269
# m7_day_auto_increment         11271
# m7_lifetime_played_runs       12122
# m7_max_run_distance           12123
# m7_total_purchases_virtual    12131
# m7_total_ads_watched          12126
# m7_total_purchases_real       12136
# m7_geo_country                11683
# m7_days_played_in_month       12124
# m7_virtual_currency_balance   12122
# m8_event_timestamp            11269
# user_pseudo_id_7                  0
# m8_mission_completed           9107
# m8_mission_id                  9397
# m8_mission_difficulty          9107
# m8_mission_stars_collected     9107
# m8_day_auto_increment          9110
# m8_lifetime_played_runs        9986
# m8_max_run_distance            9987
# m8_total_purchases_virtual     9993
# m8_total_ads_watched           9990
# m8_total_purchases_real       10000
# m8_geo_country                 9620
# m8_days_played_in_month        9988
# m8_virtual_currency_balance    9986
# m8_event_timestamp_1           9107
# user_pseudo_id_8                  0
# m9_mission_completed           6003
# m9_mission_id                  6307
# m9_mission_difficulty          6003
# m9_mission_stars_collected     6003
# m9_day_auto_increment          6005
# m9_lifetime_played_runs        6900
# m9_max_run_distance            6901
# m9_total_purchases_virtual     6907
# m9_total_ads_watched           6903
# m9_total_purchases_real        6913
# m9_geo_country                 6624
# m9_days_played_in_month        6902
# m9_virtual_currency_balance    6900
# m9_event_timestamp             6003
# user_pseudo_id_9                  0
# m10_mission_completed             0
# m10_mission_id                  400
# m10_mission_difficulty            0
# m10_mission_stars_collected       0
# m10_day_auto_increment            1
# m10_lifetime_played_runs        940
# m10_max_run_distance            941
# m10_total_purchases_virtual     945
# m10_total_ads_watched           942
# m10_total_purchases_real        949
# m10_geo_country                 964
# m10_days_played_in_month        941
# m10_virtual_currency_balance    940
# m10_event_timestamp               0
# user_pseudo_id_10                 0
# target_max_day_played             0
# real_purchases_sum                0
# virtual_purchases_sum             0
# ads_sum                           0

# %%
nas[nas['na'] > 0].sort_values(by = 'na', ascending = False)
# Out:
#                                  na
# m1_total_ads_watched          20680
# m1_total_purchases_real       20680
# m1_total_purchases_virtual    20675
# m1_days_played_in_month       20659
# m1_lifetime_played_runs       20658
# m1_max_run_distance           20658
# m1_virtual_currency_balance   20658
# m1_mission_id                 20294
# m1_geo_country                19995
# m2_total_ads_watched          19877
# m2_total_purchases_real       19877
# m2_total_purchases_virtual    19870
# m2_days_played_in_month       19858
# m2_max_run_distance           19857
# m2_virtual_currency_balance   19857
# m2_lifetime_played_runs       19857
# m1_day_auto_increment         19854
# m1_mission_completed          19853
# m1_mission_difficulty         19853
# m1_mission_stars_collected    19853
# m1_event_timestamp            19853
# m2_mission_id                 19412
# m2_geo_country                19204
# m2_day_auto_increment         19045
# m2_mission_completed          19044
# m2_mission_difficulty         19044
# m2_mission_stars_collected    19044
# m2_event_timestamp            19044
# m3_total_purchases_real       18995
# m3_total_ads_watched          18993
# m3_total_purchases_virtual    18987
# m3_days_played_in_month       18976
# m3_virtual_currency_balance   18975
# m3_lifetime_played_runs       18975
# m3_max_run_distance           18975
# m3_mission_id                 18514
# m3_geo_country                18338
# m3_day_auto_increment         18157
# m3_event_timestamp            18156
# m3_mission_difficulty         18156
# m3_mission_stars_collected    18156
# m3_mission_completed          18156
# m4_total_purchases_real       17506
# m4_total_ads_watched          17501
# m4_total_purchases_virtual    17500
# m4_days_played_in_month       17490
# m4_virtual_currency_balance   17489
# m4_lifetime_played_runs       17489
# m4_max_run_distance           17489
# m4_mission_id                 16961
# m4_geo_country                16874
# m4_day_auto_increment         16656
# m4_mission_completed          16653
# m4_event_timestamp            16653
# m4_mission_difficulty         16653
# m4_mission_stars_collected    16653
# m5_total_purchases_real       16030
# m5_total_purchases_virtual    16025
# m5_total_ads_watched          16022
# m5_days_played_in_month       16015
# m5_max_run_distance           16014
# m5_virtual_currency_balance   16013
# m5_lifetime_played_runs       16013
# m5_mission_id                 15453
# m5_geo_country                15438
# m5_day_auto_increment         15174
# m5_mission_stars_collected    15171
# m5_mission_difficulty         15171
# m5_mission_completed          15171
# m5_event_timestamp            15171
# m6_total_purchases_real       14247
# m6_total_purchases_virtual    14242
# m6_total_ads_watched          14237
# m6_days_played_in_month       14234
# m6_max_run_distance           14233
# m6_virtual_currency_balance   14232
# m6_lifetime_played_runs       14232
# m6_geo_country                13710
# m6_mission_id                 13657
# m6_day_auto_increment         13388
# m6_mission_stars_collected    13386
# m6_event_timestamp            13386
# m6_mission_completed          13386
# m6_mission_difficulty         13386
# m7_total_purchases_real       12136
# m7_total_purchases_virtual    12131
# m7_total_ads_watched          12126
# m7_days_played_in_month       12124
# m7_max_run_distance           12123
# m7_virtual_currency_balance   12122
# m7_lifetime_played_runs       12122
# m7_geo_country                11683
# m7_mission_id                 11561
# m7_day_auto_increment         11271
# m8_event_timestamp            11269
# m7_mission_completed          11269
# m7_mission_stars_collected    11269
# m7_mission_difficulty         11269
# m8_total_purchases_real       10000
# m8_total_purchases_virtual     9993
# m8_total_ads_watched           9990
# m8_days_played_in_month        9988
# m8_max_run_distance            9987
# m8_virtual_currency_balance    9986
# m8_lifetime_played_runs        9986
# m8_geo_country                 9620
# m8_mission_id                  9397
# m8_day_auto_increment          9110
# m8_mission_stars_collected     9107
# m8_mission_difficulty          9107
# m8_mission_completed           9107
# m8_event_timestamp_1           9107
# m9_total_purchases_real        6913
# m9_total_purchases_virtual     6907
# m9_total_ads_watched           6903
# m9_days_played_in_month        6902
# m9_max_run_distance            6901
# m9_virtual_currency_balance    6900
# m9_lifetime_played_runs        6900
# m9_geo_country                 6624
# m9_mission_id                  6307
# m9_day_auto_increment          6005
# m9_mission_completed           6003
# m9_mission_stars_collected     6003
# m9_mission_difficulty          6003
# m9_event_timestamp             6003
# m10_geo_country                 964
# m10_total_purchases_real        949
# m10_total_purchases_virtual     945
# m10_total_ads_watched           942
# m10_max_run_distance            941
# m10_days_played_in_month        941
# m10_lifetime_played_runs        940
# m10_virtual_currency_balance    940
# m10_mission_id                  400
# m10_day_auto_increment            1

# %%
data.columns
# Out:
# Index(['user_pseudo_id', 'm1_mission_completed', 'm1_mission_id',
#        'm1_mission_difficulty', 'm1_mission_stars_collected',
#        'm1_day_auto_increment', 'm1_lifetime_played_runs',
#        'm1_max_run_distance', 'm1_total_purchases_virtual',
#        'm1_total_ads_watched',
#        ...
#        'm10_total_purchases_real', 'm10_geo_country',
#        'm10_days_played_in_month', 'm10_virtual_currency_balance',
#        'm10_event_timestamp', 'user_pseudo_id_10', 'target_max_day_played',
#        'real_purchases_sum', 'virtual_purchases_sum', 'ads_sum'],
#       dtype='object', length=155)

# %%
target = data['target_max_day_played'].value_counts()

# %%
target = pd.DataFrame(target).reset_index()

# %%
target.columns = ['max_days', 'count']

# %%
target = target.sort_values(by = 'max_days', ascending = False)
target
# Out:
#      max_days  count
# 120  10000005      1
# 118  10000004      1
# 93   10000001      6
# 73   10000000     21
# 69    9999999     29
# 116       592      1
# 114       538      1
# 111       220      1
# 109       184      1
# 122       159      1
# 105       151      1
# 112       141      1
# 106       132      1
# 113       128      1
# 119       114      1
# 108       113      1
# 115       109      1
# 121       107      1
# 102       106      2
# 103       103      2
# 97        102      4
# 104       101      2
# 107       100      1
# 100        99      4
# 110        98      1
# 94         97      6
# 117        96      1
# 98         95      4
# 91         94      7
# 96         93      5
# 87         92      8
# 89         91      7
# 88         90      8
# 92         89      7
# 99         88      4
# 101        87      4
# 95         86      5
# 83         85     12
# 75         84     19
# 86         83      8
# 85         82     10
# 90         81      7
# 76         80     18
# 82         79     13
# 80         78     15
# 84         77     12
# 70         76     28
# 79         75     15
# 78         74     17
# 81         73     13
# 77         72     18
# 74         71     19
# 72         70     22
# 67         69     33
# 71         68     25
# 66         67     33
# 68         66     33
# 65         65     38
# 64         64     38
# 63         63     40
# 60         62     48
# 62         61     42
# 61         60     44
# 59         59     48
# 58         58     55
# 57         57     57
# 56         56     64
# 54         55     68
# 53         54     74
# 55         53     65
# 50         52     79
# 52         51     77
# 51         50     78
# 49         49     85
# 48         48    123
# 47         47    134
# 46         46    134
# 45         45    137
# 42         44    170
# 44         43    167
# 41         42    177
# 43         41    168
# 40         40    210
# 39         39    232
# 37         38    257
# 38         37    247
# 36         36    288
# 35         35    330
# 34         34    355
# 33         33    391
# 32         32    441
# 31         31    466
# 30         30    530
# 29         29    582
# 28         28    633
# 27         27    723
# 26         26    830
# 25         25    891
# 24         24   1042
# 23         23   1143
# 22         22   1351
# 21         21   1457
# 20         20   1717
# 19         19   1948
# 18         18   2333
# 17         17   2584
# 16         16   2983
# 15         15   3503
# 14         14   4017
# 13         13   4802
# 12         12   5632
# 11         11   6911
# 10         10   8179
# 9           9  10122
# 8           8  12177
# 7           7  14678
# 6           6  18121
# 5           5  21898
# 3           4  26356
# 2           3  31532
# 1           2  35972
# 0           1  36195
# 4           0  23408

# %%
droplist = []
for i in target['max_days']:
    if i > 1000:
        droplist.append(i)

# %%
data = data[~data['target_max_day_played'].isin(droplist)]

# %%
# %store data
# Out:
# Stored 'data' (DataFrame)

# %%
data.to_csv('..\\project_data\\first_cleaning.csv')

# %%
droplist2 = []
for i in cols:
    if 'mission_completed' in i:
        droplist2.append(i)

# %%
data.drop(droplist2, axis = 1, inplace = True)
# Out:
# C:\Users\herat\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
for i in cols:
    if 'pseudo_id' in i:
        data.drop(i, axis = 1, inplace = True)

# %%
for i in cols:
    if 'timestamp' in i:
        data.drop(i, axis = 1, inplace = True)

# %%
cols = list(data.columns)
cols
# Out:
# ['m1_mission_id',
#  'm1_mission_difficulty',
#  'm1_mission_stars_collected',
#  'm1_day_auto_increment',
#  'm1_lifetime_played_runs',
#  'm1_max_run_distance',
#  'm1_total_purchases_virtual',
#  'm1_total_ads_watched',
#  'm1_total_purchases_real',
#  'm1_geo_country',
#  'm1_days_played_in_month',
#  'm1_virtual_currency_balance',
#  'm2_mission_id',
#  'm2_mission_difficulty',
#  'm2_mission_stars_collected',
#  'm2_day_auto_increment',
#  'm2_lifetime_played_runs',
#  'm2_max_run_distance',
#  'm2_total_purchases_virtual',
#  'm2_total_ads_watched',
#  'm2_total_purchases_real',
#  'm2_geo_country',
#  'm2_days_played_in_month',
#  'm2_virtual_currency_balance',
#  'm3_mission_id',
#  'm3_mission_difficulty',
#  'm3_mission_stars_collected',
#  'm3_day_auto_increment',
#  'm3_lifetime_played_runs',
#  'm3_max_run_distance',
#  'm3_total_purchases_virtual',
#  'm3_total_ads_watched',
#  'm3_total_purchases_real',
#  'm3_geo_country',
#  'm3_days_played_in_month',
#  'm3_virtual_currency_balance',
#  'm4_mission_id',
#  'm4_mission_difficulty',
#  'm4_mission_stars_collected',
#  'm4_day_auto_increment',
#  'm4_lifetime_played_runs',
#  'm4_max_run_distance',
#  'm4_total_purchases_virtual',
#  'm4_total_ads_watched',
#  'm4_total_purchases_real',
#  'm4_geo_country',
#  'm4_days_played_in_month',
#  'm4_virtual_currency_balance',
#  'm5_mission_id',
#  'm5_mission_difficulty',
#  'm5_mission_stars_collected',
#  'm5_day_auto_increment',
#  'm5_lifetime_played_runs',
#  'm5_max_run_distance',
#  'm5_total_purchases_virtual',
#  'm5_total_ads_watched',
#  'm5_total_purchases_real',
#  'm5_geo_country',
#  'm5_days_played_in_month',
#  'm5_virtual_currency_balance',
#  'm6_mission_id',
#  'm6_mission_difficulty',
#  'm6_mission_stars_collected',
#  'm6_day_auto_increment',
#  'm6_lifetime_played_runs',
#  'm6_max_run_distance',
#  'm6_total_purchases_virtual',
#  'm6_total_ads_watched',
#  'm6_total_purchases_real',
#  'm6_geo_country',
#  'm6_days_played_in_month',
#  'm6_virtual_currency_balance',
#  'm7_mission_id',
#  'm7_mission_difficulty',
#  'm7_mission_stars_collected',
#  'm7_day_auto_increment',
#  'm7_lifetime_played_runs',
#  'm7_max_run_distance',
#  'm7_total_purchases_virtual',
#  'm7_total_ads_watched',
#  'm7_total_purchases_real',
#  'm7_geo_country',
#  'm7_days_played_in_month',
#  'm7_virtual_currency_balance',
#  'm8_mission_id',
#  'm8_mission_difficulty',
#  'm8_mission_stars_collected',
#  'm8_day_auto_increment',
#  'm8_lifetime_played_runs',
#  'm8_max_run_distance',
#  'm8_total_purchases_virtual',
#  'm8_total_ads_watched',
#  'm8_total_purchases_real',
#  'm8_geo_country',
#  'm8_days_played_in_month',
#  'm8_virtual_currency_balance',
#  'm9_mission_id',
#  'm9_mission_difficulty',
#  'm9_mission_stars_collected',
#  'm9_day_auto_increment',
#  'm9_lifetime_played_runs',
#  'm9_max_run_distance',
#  'm9_total_purchases_virtual',
#  'm9_total_ads_watched',
#  'm9_total_purchases_real',
#  'm9_geo_country',
#  'm9_days_played_in_month',
#  'm9_virtual_currency_balance',
#  'm10_mission_id',
#  'm10_mission_difficulty',
#  'm10_mission_stars_collected',
#  'm10_day_auto_increment',
#  'm10_lifetime_played_runs',
#  'm10_max_run_distance',
#  'm10_total_purchases_virtual',
#  'm10_total_ads_watched',
#  'm10_total_purchases_real',
#  'm10_geo_country',
#  'm10_days_played_in_month',
#  'm10_virtual_currency_balance',
#  'target_max_day_played',
#  'real_purchases_sum',
#  'virtual_purchases_sum',
#  'ads_sum']

# %% [markdown]
# ### Getting original target

# %%
target = data[['target_max_day_played']]

# %%
data.dropna(axis = 0, inplace = True)
# Out:
# C:\Users\herat\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
data.isna().sum()
# Out:
# m1_mission_id                   0
# m1_mission_difficulty           0
# m1_mission_stars_collected      0
# m1_day_auto_increment           0
# m1_lifetime_played_runs         0
# m1_max_run_distance             0
# m1_total_purchases_virtual      0
# m1_total_ads_watched            0
# m1_total_purchases_real         0
# m1_geo_country                  0
# m1_days_played_in_month         0
# m1_virtual_currency_balance     0
# m2_mission_id                   0
# m2_mission_difficulty           0
# m2_mission_stars_collected      0
# m2_day_auto_increment           0
# m2_lifetime_played_runs         0
# m2_max_run_distance             0
# m2_total_purchases_virtual      0
# m2_total_ads_watched            0
# m2_total_purchases_real         0
# m2_geo_country                  0
# m2_days_played_in_month         0
# m2_virtual_currency_balance     0
# m3_mission_id                   0
# m3_mission_difficulty           0
# m3_mission_stars_collected      0
# m3_day_auto_increment           0
# m3_lifetime_played_runs         0
# m3_max_run_distance             0
# m3_total_purchases_virtual      0
# m3_total_ads_watched            0
# m3_total_purchases_real         0
# m3_geo_country                  0
# m3_days_played_in_month         0
# m3_virtual_currency_balance     0
# m4_mission_id                   0
# m4_mission_difficulty           0
# m4_mission_stars_collected      0
# m4_day_auto_increment           0
# m4_lifetime_played_runs         0
# m4_max_run_distance             0
# m4_total_purchases_virtual      0
# m4_total_ads_watched            0
# m4_total_purchases_real         0
# m4_geo_country                  0
# m4_days_played_in_month         0
# m4_virtual_currency_balance     0
# m5_mission_id                   0
# m5_mission_difficulty           0
# m5_mission_stars_collected      0
# m5_day_auto_increment           0
# m5_lifetime_played_runs         0
# m5_max_run_distance             0
# m5_total_purchases_virtual      0
# m5_total_ads_watched            0
# m5_total_purchases_real         0
# m5_geo_country                  0
# m5_days_played_in_month         0
# m5_virtual_currency_balance     0
# m6_mission_id                   0
# m6_mission_difficulty           0
# m6_mission_stars_collected      0
# m6_day_auto_increment           0
# m6_lifetime_played_runs         0
# m6_max_run_distance             0
# m6_total_purchases_virtual      0
# m6_total_ads_watched            0
# m6_total_purchases_real         0
# m6_geo_country                  0
# m6_days_played_in_month         0
# m6_virtual_currency_balance     0
# m7_mission_id                   0
# m7_mission_difficulty           0
# m7_mission_stars_collected      0
# m7_day_auto_increment           0
# m7_lifetime_played_runs         0
# m7_max_run_distance             0
# m7_total_purchases_virtual      0
# m7_total_ads_watched            0
# m7_total_purchases_real         0
# m7_geo_country                  0
# m7_days_played_in_month         0
# m7_virtual_currency_balance     0
# m8_mission_id                   0
# m8_mission_difficulty           0
# m8_mission_stars_collected      0
# m8_day_auto_increment           0
# m8_lifetime_played_runs         0
# m8_max_run_distance             0
# m8_total_purchases_virtual      0
# m8_total_ads_watched            0
# m8_total_purchases_real         0
# m8_geo_country                  0
# m8_days_played_in_month         0
# m8_virtual_currency_balance     0
# m9_mission_id                   0
# m9_mission_difficulty           0
# m9_mission_stars_collected      0
# m9_day_auto_increment           0
# m9_lifetime_played_runs         0
# m9_max_run_distance             0
# m9_total_purchases_virtual      0
# m9_total_ads_watched            0
# m9_total_purchases_real         0
# m9_geo_country                  0
# m9_days_played_in_month         0
# m9_virtual_currency_balance     0
# m10_mission_id                  0
# m10_mission_difficulty          0
# m10_mission_stars_collected     0
# m10_day_auto_increment          0
# m10_lifetime_played_runs        0
# m10_max_run_distance            0
# m10_total_purchases_virtual     0
# m10_total_ads_watched           0
# m10_total_purchases_real        0
# m10_geo_country                 0
# m10_days_played_in_month        0
# m10_virtual_currency_balance    0
# target_max_day_played           0
# real_purchases_sum              0
# virtual_purchases_sum           0
# ads_sum                         0
# dtype: int64

# %%
data.shape
# Out:
# (267245, 124)

# %% [markdown]
# ### Exploring different columns

# %%
data.describe().T
# Out:
#                                  count           mean           std    min  \
# m1_mission_id                 267245.0     113.125465  4.788154e+00    3.0
# m1_mission_difficulty         267245.0       1.047803  2.134013e-01    1.0
# m1_mission_stars_collected    267245.0       2.828547  3.467298e+00    0.0
# m1_day_auto_increment         267245.0       0.202533  5.308777e-01   -1.0
# m1_lifetime_played_runs       267245.0       1.213572  1.532530e+00    0.0
# m1_max_run_distance           267245.0    1471.578207  5.256240e+02    0.0
# m1_total_purchases_virtual    267245.0   26451.797422  3.306831e+05    0.0
# m1_total_ads_watched          267245.0       0.065816  6.522779e-01    0.0
# m1_total_purchases_real       267245.0       0.011918  4.648891e-01    0.0
# m1_days_played_in_month       267245.0       0.154704  4.313401e-01   -1.0
# m1_virtual_currency_balance   267245.0  464702.664559  2.108958e+07    0.0
# m2_mission_id                 267245.0     106.030268  2.324327e+01    3.0
# m2_mission_difficulty         267245.0       1.009583  9.753779e-02    1.0
# m2_mission_stars_collected    267245.0       3.386469  3.452656e+00    0.0
# m2_day_auto_increment         267245.0       0.243178  5.987031e-01   -1.0
# m2_lifetime_played_runs       267245.0       1.736291  2.189666e+00    0.0
# m2_max_run_distance           267245.0    1553.197040  5.128681e+02    0.0
# m2_total_purchases_virtual    267245.0   28144.003087  3.413431e+05    0.0
# m2_total_ads_watched          267245.0       0.207858  9.316831e-01    0.0
# m2_total_purchases_real       267245.0       0.012817  4.953917e-01    0.0
# m2_days_played_in_month       267245.0       0.184426  4.787674e-01   -1.0
# m2_virtual_currency_balance   267245.0  482176.051821  2.157201e+07    0.0
# m3_mission_id                 267245.0      94.181893  3.783753e+01    3.0
# m3_mission_difficulty         267245.0       1.003828  6.193352e-02    1.0
# m3_mission_stars_collected    267245.0       4.098932  3.512844e+00    0.0
# m3_day_auto_increment         267245.0       0.284372  6.663143e-01   -1.0
# m3_lifetime_played_runs       267245.0       2.239915  2.572453e+00    0.0
# m3_max_run_distance           267245.0    1651.393542  5.614046e+02    0.0
# m3_total_purchases_virtual    267245.0   29556.364426  3.495545e+05    0.0
# m3_total_ads_watched          267245.0       0.385380  1.192268e+00    0.0
# m3_total_purchases_real       267245.0       0.013740  5.068449e-01    0.0
# m3_days_played_in_month       267245.0       0.214698  5.273367e-01   -1.0
# m3_virtual_currency_balance   267245.0  495062.776310  2.200084e+07    0.0
# m4_mission_id                 267245.0      41.548149  4.904133e+01    3.0
# m4_mission_difficulty         267245.0       1.002728  5.230077e-02    1.0
# m4_mission_stars_collected    267245.0       5.421654  3.494053e+00    1.0
# m4_day_auto_increment         267245.0       0.371760  7.867185e-01   -1.0
# m4_lifetime_played_runs       267245.0       3.165541  3.475988e+00    0.0
# m4_max_run_distance           267245.0    1977.418481  7.941260e+02    0.0
# m4_total_purchases_virtual    267245.0   32186.293959  3.645831e+05    0.0
# m4_total_ads_watched          267245.0       0.842762  1.791942e+00    0.0
# m4_total_purchases_real       267245.0       0.016092  5.329799e-01    0.0
# m4_days_played_in_month       267245.0       0.281513  6.172215e-01   -1.0
# m4_virtual_currency_balance   267245.0  507109.653617  2.216423e+07    0.0
# m5_mission_id                 267245.0      37.983584  4.961738e+01    3.0
# m5_mission_difficulty         267245.0       1.002062  4.544248e-02    1.0
# m5_mission_stars_collected    267245.0       6.428423  3.488643e+00    2.0
# m5_day_auto_increment         267245.0       0.474198  9.104287e-01   -1.0
# m5_lifetime_played_runs       267245.0       4.249988  4.481897e+00    1.0
# m5_max_run_distance           267245.0    2274.646354  9.656616e+02    0.0
# m5_total_purchases_virtual    267245.0   33691.727220  3.711788e+05    0.0
# m5_total_ads_watched          267245.0       1.458613  2.516237e+00    0.0
# m5_total_purchases_real       267245.0       0.018541  5.736027e-01    0.0
# m5_days_played_in_month       267245.0       0.360755  7.113003e-01   -1.0
# m5_virtual_currency_balance   267245.0  504338.727374  2.205821e+07    0.0
# m6_mission_id                 267245.0      41.297162  4.815722e+01    3.0
# m6_mission_difficulty         267245.0       1.231159  4.216011e-01    1.0
# m6_mission_stars_collected    267245.0       7.555685  3.490203e+00    3.0
# m6_day_auto_increment         267245.0       0.599794  1.052604e+00   -1.0
# m6_lifetime_played_runs       267245.0       5.660865  5.830876e+00    0.0
# m6_max_run_distance           267245.0    2587.851110  1.085993e+03    0.0
# m6_total_purchases_virtual    267245.0   35028.697278  3.767456e+05    0.0
# m6_total_ads_watched          267245.0       2.205269  3.290652e+00    0.0
# m6_total_purchases_real       267245.0       0.021686  6.089866e-01    0.0
# m6_days_played_in_month       267245.0       0.456802  8.122599e-01   -1.0
# m6_virtual_currency_balance   267245.0  501785.251350  2.195374e+07    0.0
# m7_mission_id                 267245.0      28.688308  3.754181e+01    3.0
# m7_mission_difficulty         267245.0       1.511654  4.998651e-01    1.0
# m7_mission_stars_collected    267245.0       8.821628  3.500857e+00    3.0
# m7_day_auto_increment         267245.0       0.763401  1.228515e+00   -1.0
# m7_lifetime_played_runs       267245.0       7.425662  7.054902e+00    1.0
# m7_max_run_distance           267245.0    2827.535247  1.167788e+03  147.0
# m7_total_purchases_virtual    267245.0   36935.268671  3.840413e+05    0.0
# m7_total_ads_watched          267245.0       3.087706  4.234116e+00    0.0
# m7_total_purchases_real       267245.0       0.026439  6.608792e-01    0.0
# m7_days_played_in_month       267245.0       0.579723  9.365062e-01   -1.0
# m7_virtual_currency_balance   267245.0  503805.288522  2.195582e+07    0.0
# m8_mission_id                 267245.0      56.437583  3.825234e+01    3.0
# m8_mission_difficulty         267245.0       1.793201  4.050293e-01    1.0
# m8_mission_stars_collected    267245.0      10.427974  3.540273e+00    0.0
# m8_day_auto_increment         267245.0       0.901506  1.358405e+00   -1.0
# m8_lifetime_played_runs       267245.0       8.958020  7.622916e+00    0.0
# m8_max_run_distance           267245.0    2994.710472  1.198450e+03    0.0
# m8_total_purchases_virtual    267245.0   38096.540800  3.881061e+05    0.0
# m8_total_ads_watched          267245.0       3.880731  4.980372e+00    0.0
# m8_total_purchases_real       267245.0       0.030506  7.021534e-01    0.0
# m8_days_played_in_month       267245.0       0.680147  1.022601e+00   -1.0
# m8_virtual_currency_balance   267245.0  510429.006702  2.204584e+07    0.0
# m9_mission_id                 267245.0      44.220779  3.880250e+01    3.0
# m9_mission_difficulty         267245.0       1.695545  4.601851e-01    1.0
# m9_mission_stars_collected    267245.0      12.130872  3.539367e+00    0.0
# m9_day_auto_increment         267245.0       1.128107  1.614993e+00   -1.0
# m9_lifetime_played_runs       267245.0      11.347498  9.311106e+00    1.0
# m9_max_run_distance           267245.0    3151.296144  1.251359e+03  151.0
# m9_total_purchases_virtual    267245.0   39630.778196  3.927473e+05    0.0
# m9_total_ads_watched          267245.0       4.983371  6.412032e+00    0.0
# m9_total_purchases_real       267245.0       0.034241  7.319110e-01    0.0
# m9_days_played_in_month       267245.0       0.833651  1.178233e+00   -1.0
# m9_virtual_currency_balance   267245.0  512189.682598  2.204952e+07    0.0
# m10_mission_id                267245.0      27.551269  3.023512e+01    3.0
# m10_mission_difficulty        267245.0       1.493053  4.999676e-01    1.0
# m10_mission_stars_collected   267245.0      13.985620  3.516653e+00    2.0
# m10_day_auto_increment        267245.0       1.600138  2.141652e+00   -1.0
# m10_lifetime_played_runs      267245.0      15.616588  1.248201e+01    1.0
# m10_max_run_distance          267245.0    3353.489468  1.334712e+03  151.0
# m10_total_purchases_virtual   267245.0   44265.133076  4.184607e+05    0.0
# m10_total_ads_watched         267245.0       7.105922  9.644433e+00    0.0
# m10_total_purchases_real      267245.0       0.040606  8.201980e-01    0.0
# m10_days_played_in_month      267245.0       1.115310  1.460939e+00   -1.0
# m10_virtual_currency_balance  267245.0  519922.406208  2.216946e+07    0.0
# target_max_day_played         267245.0       6.425198  8.125845e+00    0.0
# real_purchases_sum            267245.0       0.226586  5.761758e+00    0.0
# virtual_purchases_sum         267245.0  343986.604135  3.623241e+06    0.0
# ads_sum                       267245.0      24.223428  3.077806e+01    0.0
#
#                                  25%      50%      75%           max
# m1_mission_id                  113.0    115.0    115.0  1.220000e+02
# m1_mission_difficulty            1.0      1.0      1.0  3.000000e+00
# m1_mission_stars_collected       3.0      3.0      3.0  1.759000e+03
# m1_day_auto_increment            0.0      0.0      0.0  3.500000e+01
# m1_lifetime_played_runs          1.0      1.0      1.0  4.540000e+02
# m1_max_run_distance           1173.0   1345.0   1657.0  2.464800e+04
# m1_total_purchases_virtual       0.0      0.0   1500.0  6.119500e+06
# m1_total_ads_watched             0.0      0.0      0.0  1.870000e+02
# m1_total_purchases_real          0.0      0.0      0.0  7.393000e+01
# m1_days_played_in_month          0.0      0.0      0.0  1.400000e+01
# m1_virtual_currency_balance   5243.0   5510.0   5621.0  1.997650e+09
# m2_mission_id                  109.0    113.0    113.0  1.220000e+02
# m2_mission_difficulty            1.0      1.0      1.0  3.000000e+00
# m2_mission_stars_collected       3.0      3.0      4.0  1.760000e+03
# m2_day_auto_increment            0.0      0.0      0.0  3.700000e+01
# m2_lifetime_played_runs          1.0      2.0      2.0  4.540000e+02
# m2_max_run_distance           1211.0   1403.0   1756.0  2.464800e+04
# m2_total_purchases_virtual       0.0      0.0   1500.0  6.165500e+06
# m2_total_ads_watched             0.0      0.0      0.0  1.900000e+02
# m2_total_purchases_real          0.0      0.0      0.0  7.876000e+01
# m2_days_played_in_month          0.0      0.0      0.0  1.600000e+01
# m2_virtual_currency_balance   4388.0   5542.0   5692.0  2.146000e+09
# m3_mission_id                  109.0    109.0    113.0  1.220000e+02
# m3_mission_difficulty            1.0      1.0      1.0  3.000000e+00
# m3_mission_stars_collected       3.0      4.0      5.0  1.761000e+03
# m3_day_auto_increment            0.0      0.0      0.0  3.800000e+01
# m3_lifetime_played_runs          2.0      2.0      2.0  4.540000e+02
# m3_max_run_distance           1269.0   1492.0   1909.0  2.464800e+04
# m3_total_purchases_virtual       0.0      0.0   1500.0  6.165500e+06
# m3_total_ads_watched             0.0      0.0      0.0  1.930000e+02
# m3_total_purchases_real          0.0      0.0      0.0  7.876000e+01
# m3_days_played_in_month          0.0      0.0      0.0  1.700000e+01
# m3_virtual_currency_balance   4247.0   5577.0   5764.0  2.146000e+09
# m4_mission_id                   11.0     11.0    113.0  1.220000e+02
# m4_mission_difficulty            1.0      1.0      1.0  3.000000e+00
# m4_mission_stars_collected       5.0      6.0      6.0  1.761000e+03
# m4_day_auto_increment            0.0      0.0      1.0  4.100000e+01
# m4_lifetime_played_runs          2.0      2.0      3.0  4.540000e+02
# m4_max_run_distance           1424.0   1789.0   2320.0  2.464800e+04
# m4_total_purchases_virtual       0.0      0.0   2000.0  6.165500e+06
# m4_total_ads_watched             0.0      0.0      1.0  1.980000e+02
# m4_total_purchases_real          0.0      0.0      0.0  7.876000e+01
# m4_days_played_in_month          0.0      0.0      0.0  1.700000e+01
# m4_virtual_currency_balance   4270.0   5711.0   6224.0  2.146000e+09
# m5_mission_id                    3.0     11.0    114.0  1.220000e+02
# m5_mission_difficulty            1.0      1.0      1.0  3.000000e+00
# m5_mission_stars_collected       6.0      7.0      7.0  1.765000e+03
# m5_day_auto_increment            0.0      0.0      1.0  4.100000e+01
# m5_lifetime_played_runs          2.0      3.0      5.0  4.540000e+02
# m5_max_run_distance           1598.0   2070.0   2653.0  2.464800e+04
# m5_total_purchases_virtual       0.0      0.0   3000.0  6.226500e+06
# m5_total_ads_watched             0.0      1.0      2.0  2.170000e+02
# m5_total_purchases_real          0.0      0.0      0.0  7.991000e+01
# m5_days_played_in_month          0.0      0.0      1.0  1.800000e+01
# m5_virtual_currency_balance   4070.0   5939.0   6574.0  2.146000e+09
# m6_mission_id                    6.0     19.0    114.0  1.220000e+02
# m6_mission_difficulty            1.0      1.0      1.0  3.000000e+00
# m6_mission_stars_collected       7.0      8.0      8.0  1.766000e+03
# m6_day_auto_increment            0.0      0.0      1.0  4.500000e+01
# m6_lifetime_played_runs          3.0      4.0      6.0  4.540000e+02
# m6_max_run_distance           1848.0   2350.0   3048.0  2.464800e+04
# m6_total_purchases_virtual       0.0   1000.0   4000.0  6.254500e+06
# m6_total_ads_watched             0.0      1.0      3.0  2.200000e+02
# m6_total_purchases_real          0.0      0.0      0.0  9.470000e+01
# m6_days_played_in_month          0.0      0.0      1.0  1.800000e+01
# m6_virtual_currency_balance   3557.0   6238.0   7054.0  2.146000e+09
# m7_mission_id                    6.0     19.0     19.0  1.220000e+02
# m7_mission_difficulty            1.0      2.0      2.0  2.000000e+00
# m7_mission_stars_collected       8.0      9.0      9.0  1.768000e+03
# m7_day_auto_increment            0.0      0.0      1.0  5.000000e+01
# m7_lifetime_played_runs          4.0      6.0      8.0  4.540000e+02
# m7_max_run_distance           2048.0   2573.0   3334.0  2.464800e+04
# m7_total_purchases_virtual       0.0   1500.0   5500.0  6.254500e+06
# m7_total_ads_watched             0.0      2.0      4.0  2.250000e+02
# m7_total_purchases_real          0.0      0.0      0.0  9.669000e+01
# m7_days_played_in_month          0.0      0.0      1.0  2.000000e+01
# m7_virtual_currency_balance   3438.0   6631.0   8059.0  2.146000e+09
# m8_mission_id                   12.0     86.0     86.0  1.220000e+02
# m8_mission_difficulty            2.0      2.0      2.0  3.000000e+00
# m8_mission_stars_collected      10.0     11.0     11.0  1.769000e+03
# m8_day_auto_increment            0.0      0.0      1.0  5.100000e+01
# m8_lifetime_played_runs          5.0      7.0     10.0  4.540000e+02
# m8_max_run_distance           2195.0   2735.0   3521.0  2.464800e+04
# m8_total_purchases_virtual       0.0   1500.0   6000.0  6.320500e+06
# m8_total_ads_watched             0.0      3.0      6.0  2.300000e+02
# m8_total_purchases_real          0.0      0.0      0.0  9.669000e+01
# m8_days_played_in_month          0.0      0.0      1.0  2.000000e+01
# m8_virtual_currency_balance   3127.0   7029.0   8750.0  2.146000e+09
# m9_mission_id                   10.0     19.0     86.0  1.220000e+02
# m9_mission_difficulty            1.0      2.0      2.0  3.000000e+00
# m9_mission_stars_collected      12.0     12.0     13.0  1.769000e+03
# m9_day_auto_increment            0.0      1.0      2.0  5.200000e+01
# m9_lifetime_played_runs          6.0      9.0     14.0  4.540000e+02
# m9_max_run_distance           2313.0   2884.0   3703.0  2.464800e+04
# m9_total_purchases_virtual       0.0   2500.0   7500.0  7.904500e+06
# m9_total_ads_watched             0.0      3.0      7.0  2.350000e+02
# m9_total_purchases_real          0.0      0.0      0.0  9.669000e+01
# m9_days_played_in_month          0.0      0.0      1.0  2.400000e+01
# m9_virtual_currency_balance   2759.0   7188.0   9306.0  2.146000e+09
# m10_mission_id                  10.0     12.0     19.0  1.220000e+02
# m10_mission_difficulty           1.0      1.0      2.0  3.000000e+00
# m10_mission_stars_collected     14.0     14.0     14.0  1.772000e+03
# m10_day_auto_increment           0.0      1.0      2.0  5.800000e+01
# m10_lifetime_played_runs         8.0     12.0     19.0  6.320000e+02
# m10_max_run_distance          2456.0   3072.0   3936.0  2.846300e+04
# m10_total_purchases_virtual      0.0   4500.0  10000.0  8.099500e+06
# m10_total_ads_watched            0.0      4.0     10.0  2.390000e+02
# m10_total_purchases_real         0.0      0.0      0.0  1.339300e+02
# m10_days_played_in_month         0.0      1.0      2.0  2.500000e+01
# m10_virtual_currency_balance  2636.0   7273.0  10541.0  2.146000e+09
# target_max_day_played            2.0      4.0      8.0  5.920000e+02
# real_purchases_sum               0.0      0.0      0.0  8.124400e+02
# virtual_purchases_sum            0.0  18000.0  43000.0  6.404100e+07
# ads_sum                          0.0     16.0     35.0  2.134000e+03

# %% [markdown]
# ### Getting smaller datasets for each mission

# %%
dataset1 = []

for i in cols:
    if ('m1_' in i) | ('target_max_day_played' in i):
        dataset1.append(i)
dataset1 = data[dataset1].reset_index()
dataset1.columns
# Out:
# Index(['index', 'm1_mission_id', 'm1_mission_difficulty',
#        'm1_mission_stars_collected', 'm1_day_auto_increment',
#        'm1_lifetime_played_runs', 'm1_max_run_distance',
#        'm1_total_purchases_virtual', 'm1_total_ads_watched',
#        'm1_total_purchases_real', 'm1_geo_country', 'm1_days_played_in_month',
#        'm1_virtual_currency_balance', 'target_max_day_played'],
#       dtype='object')

# %%
dataset2 = []

for i in cols:
    if ('m2' in i) | ('target_max_day_played' in i):
        dataset2.append(i)
dataset2 = data[dataset2].reset_index()
dataset2.columns
# Out:
# Index(['index', 'm2_mission_id', 'm2_mission_difficulty',
#        'm2_mission_stars_collected', 'm2_day_auto_increment',
#        'm2_lifetime_played_runs', 'm2_max_run_distance',
#        'm2_total_purchases_virtual', 'm2_total_ads_watched',
#        'm2_total_purchases_real', 'm2_geo_country', 'm2_days_played_in_month',
#        'm2_virtual_currency_balance', 'target_max_day_played'],
#       dtype='object')

# %%
dataset3 = []

for i in cols:
    if ('m3' in i) | ('target_max_day_played' in i):
        dataset3.append(i)
dataset3 = data[dataset3].reset_index()
dataset3.shape
# Out:
# (267245, 14)

# %%
dataset4 = []

for i in cols:
    if ('m4' in i) | ('target_max_day_played' in i):
        dataset4.append(i)
dataset4 = data[dataset4].reset_index()
dataset4.shape
# Out:
# (267245, 14)

# %%
dataset5 = []

for i in cols:
    if ('m5' in i) | ('target_max_day_played' in i):
        dataset5.append(i)
dataset5 = data[dataset5].reset_index()
dataset5.shape
# Out:
# (267245, 14)

# %%
dataset6 = []

for i in cols:
    if ('m6' in i) | ('target_max_day_played' in i):
        dataset6.append(i)
dataset6 = data[dataset6].reset_index()
dataset6.shape
# Out:
# (267245, 14)

# %%
dataset7 = []

for i in cols:
    if ('m7' in i) | ('target_max_day_played' in i):
        dataset7.append(i)
dataset7 = data[dataset7].reset_index()
dataset7.shape
# Out:
# (267245, 14)

# %%
dataset8 = []

for i in cols:
    if ('m8' in i) | ('target_max_day_played' in i):
        dataset8.append(i)
dataset8 = data[dataset8].reset_index()
dataset8.shape
# Out:
# (267245, 14)

# %%
dataset9 = []

for i in cols:
    if ('m9' in i) | ('target_max_day_played' in i):
        dataset9.append(i)
dataset9 = data[dataset9].reset_index()
dataset9.shape
# Out:
# (267245, 14)

# %%
dataset10 = []

for i in cols:
    if ('m10' in i) | ('target_max_day_played' in i):
        dataset10.append(i)
dataset10 = data[dataset10].reset_index()
dataset10.shape
# Out:
# (267245, 14)

# %%
dataset9.head()
# Out:
#    index  m9_mission_id  m9_mission_difficulty  m9_mission_stars_collected  \
# 0      0           86.0                    2.0                        12.0
# 1      1           19.0                    2.0                        11.0
# 2      2           12.0                    2.0                        13.0
# 3      3           86.0                    2.0                        13.0
# 4      4           12.0                    2.0                        13.0
#
#    m9_day_auto_increment  m9_lifetime_played_runs  m9_max_run_distance  \
# 0                    3.0                     21.0               2585.0
# 1                    0.0                      4.0               3790.0
# 2                    2.0                     12.0               3581.0
# 3                    1.0                     15.0               2261.0
# 4                    1.0                     26.0               2538.0
#
#    m9_total_purchases_virtual  m9_total_ads_watched  m9_total_purchases_real  \
# 0                      7000.0                   0.0                      0.0
# 1                         0.0                   2.0                      0.0
# 2                      1000.0                   8.0                      0.0
# 3                      5500.0                   0.0                      0.0
# 4                      1500.0                   0.0                      0.0
#
#   m9_geo_country  m9_days_played_in_month  m9_virtual_currency_balance  \
# 0       Honduras                      3.0                       3322.0
# 1        Belgium                      0.0                       9379.0
# 2        Vietnam                      2.0                       8657.0
# 3         Taiwan                      1.0                       2055.0
# 4     Bangladesh                      1.0                      11848.0
#
#    target_max_day_played
# 0                      4
# 1                      4
# 2                      2
# 3                      2
# 4                      5

# %%
datasets = [dataset1, dataset2, dataset3, dataset4, dataset5, dataset6, dataset7, dataset8, dataset9, dataset10]

# %%
x = 1
for i in datasets:
    i['mission_played'] = x
    x += 1

# %%
dataset1.columns
# Out:
# Index(['index', 'm1_mission_id', 'm1_mission_difficulty',
#        'm1_mission_stars_collected', 'm1_day_auto_increment',
#        'm1_lifetime_played_runs', 'm1_max_run_distance',
#        'm1_total_purchases_virtual', 'm1_total_ads_watched',
#        'm1_total_purchases_real', 'm1_geo_country', 'm1_days_played_in_month',
#        'm1_virtual_currency_balance', 'target_max_day_played',
#        'mission_played'],
#       dtype='object')

# %%
for i in datasets:
        i.columns = ['pseudo_id', 'mission_id', 'mission_difficulty',
       'mission_stars_collected', 'day_auto_increment',
       'lifetime_played_runs', 'max_run_distance',
       'total_purchases_virtual', 'total_ads_watched',
       'total_purchases_real', 'geo_country', 'days_played_in_month',
       'virtual_currency_balance', 'target_max_day_played',
       'mission_played']

# %%
dataset1.dtypes
# Out:
# pseudo_id                     int64
# mission_id                  float64
# mission_difficulty          float64
# mission_stars_collected     float64
# day_auto_increment          float64
# lifetime_played_runs        float64
# max_run_distance            float64
# total_purchases_virtual     float64
# total_ads_watched           float64
# total_purchases_real        float64
# geo_country                  object
# days_played_in_month        float64
# virtual_currency_balance    float64
# target_max_day_played         int64
# mission_played                int64
# dtype: object

# %%
clean_data = pd.concat(datasets, axis = 0)

# %%
clean_data['mission_played'].value_counts()
# Out:
# 1     267245
# 2     267245
# 3     267245
# 4     267245
# 5     267245
# 6     267245
# 7     267245
# 8     267245
# 9     267245
# 10    267245
# Name: mission_played, dtype: int64

# %%
cols = list(clean_data.columns)
cols.remove('geo_country')

# %%
for i in cols:
    clean_data[i] = clean_data[i].astype(int)

# %%
clean_data.dtypes
# Out:
# pseudo_id                    int32
# mission_id                   int32
# mission_difficulty           int32
# mission_stars_collected      int32
# day_auto_increment           int32
# lifetime_played_runs         int32
# max_run_distance             int32
# total_purchases_virtual      int32
# total_ads_watched            int32
# total_purchases_real         int32
# geo_country                 object
# days_played_in_month         int32
# virtual_currency_balance     int32
# target_max_day_played        int32
# mission_played               int32
# dtype: object

# %%
clean_data.sort_values(by = ['pseudo_id', 'mission_played'])
# Out:
#         pseudo_id  mission_id  mission_difficulty  mission_stars_collected  \
# 0               0          94                   2                        3
# 0               0         109                   1                        4
# 0               0         115                   1                        5
# 0               0         114                   1                        6
# 0               0           3                   1                        7
# ...           ...         ...                 ...                      ...
# 172244      96733          12                   2                       12
# 267244      96733          86                   2                       12
# 77005       96733          12                   2                       14
# 172244      96733          86                   2                       14
# 267244      96733          10                   1                       14
#
#         day_auto_increment  lifetime_played_runs  max_run_distance  \
# 0                        0                     2              1763
# 0                        0                     3              2266
# 0                        0                     8              2266
# 0                        2                     9              2266
# 0                        2                    12              2266
# ...                    ...                   ...               ...
# 172244                   0                     7              1700
# 267244                   1                    14              2801
# 77005                    0                     9              3298
# 172244                   0                     7              1700
# 267244                   2                    21              4662
#
#         total_purchases_virtual  total_ads_watched  total_purchases_real  \
# 0                          2000                  0                     0
# 0                          2000                  0                     0
# 0                          3500                  0                     0
# 0                          3500                  0                     0
# 0                          7000                  0                     0
# ...                         ...                ...                   ...
# 172244                        0                  0                     0
# 267244                     5500                 14                     0
# 77005                     15000                  7                     0
# 172244                        0                  0                     0
# 267244                    21000                 22                     0
#
#            geo_country  days_played_in_month  virtual_currency_balance  \
# 0             Honduras                     0                      5000
# 0             Honduras                     0                      4238
# 0             Honduras                     0                      3561
# 0             Honduras                     2                      4284
# 0             Honduras                     2                      1306
# ...                ...                   ...                       ...
# 172244         Nigeria                     0                      5665
# 267244  United Kingdom                     1                     12680
# 77005           Brazil                     0                      3521
# 172244         Nigeria                     0                      5465
# 267244  United Kingdom                     2                      2628
#
#         target_max_day_played  mission_played
# 0                           4               1
# 0                           4               2
# 0                           4               3
# 0                           4               4
# 0                           4               5
# ...                       ...             ...
# 172244                      1               9
# 267244                      5               9
# 77005                       0              10
# 172244                      1              10
# 267244                      5              10
#
# [2672450 rows x 15 columns]

# %%
clean_data = clean_data[clean_data['day_auto_increment'] != -1]

# %%
clean_data = clean_data[clean_data['days_played_in_month'] != -1]

# %%
targets = clean_data.pivot_table(index = 'pseudo_id', values = ['total_purchases_real', 'total_ads_watched', 'total_purchases_virtual'], aggfunc = 'sum').reset_index()

# %%
targets.columns
# Out:
# Index(['pseudo_id', 'total_ads_watched', 'total_purchases_real',
#        'total_purchases_virtual'],
#       dtype='object')

# %%
targets.columns = ['pseudo_id', 'sum_ads', 'sum_purchases_real',
       'sum_purchases_virtual']

# %%
clean_data = clean_data.merge(targets, on = 'pseudo_id')

# %%
# %store clean_data
# Out:
# Stored 'clean_data' (DataFrame)

# %%
clean_data.to_csv('..\project_data\clean_data.csv')

# %%
cor1 = clean_data.corr()

# %%
clean_data1 = clean_data.sample(frac = 0.6)

# %%
sns.heatmap(cor1, annot=True)
plt.show()

# %%
X = clean_data.drop(['sum_purchases_real', 'geo_country', 'total_purchases_real'],axis=1)
y1 = clean_data['sum_purchases_real']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y1)

# %%
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train= X_train.select_dtypes(object)
categoricals_test= X_test.select_dtypes(object)

# %%
transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

# %%
encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

# %%
X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

# %%
from sklearn.metrics import mean_squared_error as sqrt

# %%
LR = LinearRegression().fit(X_train,y_train)

# %%
score = LR.score(X_test, y_test)
score
# Out:
# 0.000634932530249932

# %%
from xgboost import XGBRegressor
import xgboost as xgb

model = XGBRegressor(
    max_depth=10,
    n_estimators=200,
    min_child_weight=0.5, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.1,
    seed=42)

# %%
model.fit(
    X_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, y_train), (X_test, y_test)], 
    verbose=True, 
    early_stopping_rounds = 40)
# Out:
# C:\Users\herat\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\herat\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:8.67272	validation_1-rmse:8.59479
# [1]	validation_0-rmse:8.19710	validation_1-rmse:8.15063
# [2]	validation_0-rmse:7.91236	validation_1-rmse:7.91116
# [3]	validation_0-rmse:7.58231	validation_1-rmse:7.59587
# [4]	validation_0-rmse:7.27958	validation_1-rmse:7.30605
# [5]	validation_0-rmse:6.87538	validation_1-rmse:6.91570
# [6]	validation_0-rmse:6.71054	validation_1-rmse:6.79483
# [7]	validation_0-rmse:6.49249	validation_1-rmse:6.57487
# [8]	validation_0-rmse:6.36321	validation_1-rmse:6.47520
# [9]	validation_0-rmse:6.13375	validation_1-rmse:6.24529
# [10]	validation_0-rmse:5.86810	validation_1-rmse:5.98430
# [11]	validation_0-rmse:5.64364	validation_1-rmse:5.75880
# [59]	validation_0-rmse:3.04166	validation_1-rmse:3.25277
# [60]	validation_0-rmse:3.01638	validation_1-rmse:3.22639
# [61]	validation_0-rmse:2.99396	validation_1-rmse:3.19968
# [62]	validation_0-rmse:2.97680	validation_1-rmse:3.18459
# [63]	validation_0-rmse:2.97201	validation_1-rmse:3.18032
# [64]	validation_0-rmse:2.95496	validation_1-rmse:3.15856
# [65]	validation_0-rmse:2.93573	validation_1-rmse:3.14449
# [66]	validation_0-rmse:2.92829	validation_1-rmse:3.13686
# [67]	validation_0-rmse:2.91885	validation_1-rmse:3.12695
# [68]	validation_0-rmse:2.91394	validation_1-rmse:3.12269
# [69]	validation_0-rmse:2.89965	validation_1-rmse:3.10688
# [70]	validation_0-rmse:2.89558	validation_1-rmse:3.10294
# [71]	validation_0-rmse:2.88714	validation_1-rmse:3.09504
# [72]	validation_0-rmse:2.87863	validation_1-rmse:3.08472
# [73]	validation_0-rmse:2.87508	validation_1-rmse:3.08190
# [74]	validation_0-rmse:2.84934	validation_1-rmse:3.05455
# [75]	validation_0-rmse:2.84240	validation_1-rmse:3.04672
# [76]	validation_0-rmse:2.83485	validation_1-rmse:3.04024
# [77]	validation_0-rmse:2.82559	validation_1-rmse:3.03181
# [78]	validation_0-rmse:2.81699	validation_1-rmse:3.02462
# [79]	validation_0-rmse:2.79460	validation_1-rmse:3.00661
# [80]	validation_0-rmse:2.78755	validation_1-rmse:2.99882
# [81]	validation_0-rmse:2.77961	validation_1-rmse:2.99296
# [82]	validation_0-rmse:2.75721	validation_1-rmse:2.96954
# [83]	validation_0-rmse:2.73340	validation_1-rmse:2.94758
# [84]	validation_0-rmse:2.72426	validation_1-rmse:2.93651
# [85]	validation_0-rmse:2.70923	validation_1-rmse:2.91829
# [86]	validation_0-rmse:2.68970	validation_1-rmse:2.90250
# [87]	validation_0-rmse:2.68756	validation_1-rmse:2.90058
# [88]	validation_0-rmse:2.68426	validation_1-rmse:2.89748
# [89]	validation_0-rmse:2.67388	validation_1-rmse:2.89001
# [90]	validation_0-rmse:2.65986	validation_1-rmse:2.87725
# [91]	validation_0-rmse:2.64761	validation_1-rmse:2.86779
# [92]	validation_0-rmse:2.64385	validation_1-rmse:2.86554
# [93]	validation_0-rmse:2.64064	validation_1-rmse:2.86327
# [94]	validation_0-rmse:2.63295	validation_1-rmse:2.85916
# [95]	validation_0-rmse:2.61722	validation_1-rmse:2.84403
# [96]	validation_0-rmse:2.59785	validation_1-rmse:2.82613
# [97]	validation_0-rmse:2.59351	validation_1-rmse:2.82065
# [98]	validation_0-rmse:2.57291	validation_1-rmse:2.80002
# [99]	validation_0-rmse:2.56982	validation_1-rmse:2.79792
# [100]	validation_0-rmse:2.56035	validation_1-rmse:2.79185
# [101]	validation_0-rmse:2.55702	validation_1-rmse:2.78774
# [102]	validation_0-rmse:2.55337	validation_1-rmse:2.78424
# [103]	validation_0-rmse:2.54152	validation_1-rmse:2.77428
# [104]	validation_0-rmse:2.53906	validation_1-rmse:2.77238
# [105]	validation_0-rmse:2.53387	validation_1-rmse:2.76539
# [106]	validation_0-rmse:2.52542	validation_1-rmse:2.75660
# [107]	validation_0-rmse:2.52226	validation_1-rmse:2.75328
# [108]	validation_0-rmse:2.52011	validation_1-rmse:2.75046
# [109]	validation_0-rmse:2.51645	validation_1-rmse:2.74665
# [110]	validation_0-rmse:2.50341	validation_1-rmse:2.73189
# [111]	validation_0-rmse:2.49458	validation_1-rmse:2.72897
# [112]	validation_0-rmse:2.49146	validation_1-rmse:2.72620
# [113]	validation_0-rmse:2.47635	validation_1-rmse:2.71026
# [114]	validation_0-rmse:2.46532	validation_1-rmse:2.69777
# [115]	validation_0-rmse:2.45163	validation_1-rmse:2.68232
# [116]	validation_0-rmse:2.44737	validation_1-rmse:2.67984
# [117]	validation_0-rmse:2.44556	validation_1-rmse:2.67918
# [118]	validation_0-rmse:2.44331	validation_1-rmse:2.67691
# [119]	validation_0-rmse:2.44038	validation_1-rmse:2.67414
# [120]	validation_0-rmse:2.41525	validation_1-rmse:2.65203
# [121]	validation_0-rmse:2.40516	validation_1-rmse:2.64131
# [122]	validation_0-rmse:2.38848	validation_1-rmse:2.62425
# [123]	validation_0-rmse:2.36960	validation_1-rmse:2.60573
# [124]	validation_0-rmse:2.35477	validation_1-rmse:2.59154
# [125]	validation_0-rmse:2.33658	validation_1-rmse:2.57540
# [126]	validation_0-rmse:2.33282	validation_1-rmse:2.57285
# [127]	validation_0-rmse:2.31107	validation_1-rmse:2.55007
# [128]	validation_0-rmse:2.30431	validation_1-rmse:2.54357
# [129]	validation_0-rmse:2.29973	validation_1-rmse:2.53949
# [130]	validation_0-rmse:2.29730	validation_1-rmse:2.53697
# [131]	validation_0-rmse:2.29298	validation_1-rmse:2.53264
# [132]	validation_0-rmse:2.28794	validation_1-rmse:2.52655
# [133]	validation_0-rmse:2.28671	validation_1-rmse:2.52519
# [134]	validation_0-rmse:2.28405	validation_1-rmse:2.52272
# [135]	validation_0-rmse:2.28036	validation_1-rmse:2.51986
# [136]	validation_0-rmse:2.27537	validation_1-rmse:2.51508
# [137]	validation_0-rmse:2.27123	validation_1-rmse:2.51094
# [138]	validation_0-rmse:2.24995	validation_1-rmse:2.49282
# [139]	validation_0-rmse:2.24328	validation_1-rmse:2.48798
# [140]	validation_0-rmse:2.23643	validation_1-rmse:2.47915
# [141]	validation_0-rmse:2.22958	validation_1-rmse:2.47192
# [142]	validation_0-rmse:2.22402	validation_1-rmse:2.46690
# [143]	validation_0-rmse:2.21917	validation_1-rmse:2.46303
# [144]	validation_0-rmse:2.21445	validation_1-rmse:2.46078
# [145]	validation_0-rmse:2.21005	validation_1-rmse:2.45576
# [146]	validation_0-rmse:2.20781	validation_1-rmse:2.45338
# [147]	validation_0-rmse:2.20421	validation_1-rmse:2.44908
# [148]	validation_0-rmse:2.19912	validation_1-rmse:2.44177
# [149]	validation_0-rmse:2.19702	validation_1-rmse:2.43977
# [150]	validation_0-rmse:2.19562	validation_1-rmse:2.43798
# [151]	validation_0-rmse:2.18688	validation_1-rmse:2.42973
# [152]	validation_0-rmse:2.18497	validation_1-rmse:2.42794
# [153]	validation_0-rmse:2.17149	validation_1-rmse:2.41528
# [154]	validation_0-rmse:2.16680	validation_1-rmse:2.40931
# [155]	validation_0-rmse:2.16370	validation_1-rmse:2.40829
# [156]	validation_0-rmse:2.16292	validation_1-rmse:2.40771
# [157]	validation_0-rmse:2.16014	validation_1-rmse:2.40392
# [158]	validation_0-rmse:2.14967	validation_1-rmse:2.39362
# [159]	validation_0-rmse:2.13071	validation_1-rmse:2.37522
# [160]	validation_0-rmse:2.12419	validation_1-rmse:2.36916
# [161]	validation_0-rmse:2.11912	validation_1-rmse:2.36432
# [162]	validation_0-rmse:2.10280	validation_1-rmse:2.34797
# [163]	validation_0-rmse:2.08486	validation_1-rmse:2.33113
# [164]	validation_0-rmse:2.07862	validation_1-rmse:2.32538
# [165]	validation_0-rmse:2.06434	validation_1-rmse:2.31087
# [166]	validation_0-rmse:2.06130	validation_1-rmse:2.30774
# [167]	validation_0-rmse:2.04782	validation_1-rmse:2.29091
# [168]	validation_0-rmse:2.04163	validation_1-rmse:2.28820
# [169]	validation_0-rmse:2.03923	validation_1-rmse:2.28526
# [170]	validation_0-rmse:2.03835	validation_1-rmse:2.28462
# [171]	validation_0-rmse:2.02929	validation_1-rmse:2.28092
# [172]	validation_0-rmse:2.00631	validation_1-rmse:2.25872
# [173]	validation_0-rmse:1.99644	validation_1-rmse:2.25120
# [174]	validation_0-rmse:1.99334	validation_1-rmse:2.24829
# [175]	validation_0-rmse:1.99136	validation_1-rmse:2.24592
# [176]	validation_0-rmse:1.98977	validation_1-rmse:2.24530
# [177]	validation_0-rmse:1.98177	validation_1-rmse:2.23864
# [178]	validation_0-rmse:1.98090	validation_1-rmse:2.23773
# [179]	validation_0-rmse:1.97868	validation_1-rmse:2.23555
# [180]	validation_0-rmse:1.95915	validation_1-rmse:2.21520
# [181]	validation_0-rmse:1.95138	validation_1-rmse:2.20908
# [182]	validation_0-rmse:1.95070	validation_1-rmse:2.20809
# [183]	validation_0-rmse:1.94875	validation_1-rmse:2.20635
# [184]	validation_0-rmse:1.92759	validation_1-rmse:2.19054
# [185]	validation_0-rmse:1.92422	validation_1-rmse:2.18664
# [186]	validation_0-rmse:1.91877	validation_1-rmse:2.18139
# [187]	validation_0-rmse:1.91213	validation_1-rmse:2.17366
# [188]	validation_0-rmse:1.90496	validation_1-rmse:2.16699
# [189]	validation_0-rmse:1.89485	validation_1-rmse:2.15938
# [190]	validation_0-rmse:1.88648	validation_1-rmse:2.15131
# [191]	validation_0-rmse:1.88459	validation_1-rmse:2.14920
# [192]	validation_0-rmse:1.87635	validation_1-rmse:2.14281
# [193]	validation_0-rmse:1.86937	validation_1-rmse:2.13677
# [194]	validation_0-rmse:1.86837	validation_1-rmse:2.13630
# [195]	validation_0-rmse:1.84247	validation_1-rmse:2.10674
# [196]	validation_0-rmse:1.84182	validation_1-rmse:2.10628
# [197]	validation_0-rmse:1.83863	validation_1-rmse:2.10520
# [198]	validation_0-rmse:1.83546	validation_1-rmse:2.10239
# [199]	validation_0-rmse:1.83467	validation_1-rmse:2.10194
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.8,
#              early_stopping_rounds=None, enable_categorical=False, eta=0.1,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.100000001, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=0.5,
#              missing=nan, monotone_constraints='()', n_estimators=200, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=42,
#              reg_alpha=0, ...)

# %%
xgb.plot_importance(model, )
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
X = clean_data1.drop(['total_purchases_virtual', 'sum_purchases_virtual', 'geo_country'],axis=1)
y2 = clean_data1['sum_purchases_virtual']

X_train, X_test, y_train, y_test = train_test_split(X,y2)

numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train= X_train.select_dtypes(object)
categoricals_test= X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

X_train = np.concatenate((numericals_train_standardized,categoricals_train),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test),axis=1)

LR = LinearRegression().fit(X_train,y_train)

score = LR.score(X_test, y_test)
score
# Out:
# 0.017464557481684184

# %%
clean_data1
# Out:
#          pseudo_id  mission_id  mission_difficulty  mission_stars_collected  \
# 2246682      95782         113                   1                        3
# 6027           211         114                   1                        8
# 16340          578           6                   1                       11
# 2156777      92704          11                   1                        5
# 1528218      71102          12                   2                       14
# ...            ...         ...                 ...                      ...
# 1286975      62794          11                   1                        5
# 556618       19298         114                   1                        7
# 644359       22333          11                   1                        6
# 620607       21515         114                   1                        7
# 1531412      71211           3                   1                        7
#
#          day_auto_increment  lifetime_played_runs  max_run_distance  \
# 2246682                   0                     1              1264
# 6027                      1                    12              2784
# 16340                     3                    12              1712
# 2156777                   2                     5              1443
# 1528218                   0                     7              5769
# ...                     ...                   ...               ...
# 1286975                   0                     2              2260
# 556618                    1                     6              2594
# 644359                    0                     5              1340
# 620607                    2                     6              3557
# 1531412                   0                     3              4373
#
#          total_purchases_virtual  total_ads_watched  total_purchases_real  \
# 2246682                        0                  0                     0
# 6027                        8000                  0                     0
# 16340                       1500                  0                     0
# 2156777                        0                  0                     0
# 1528218                        0                  0                     0
# ...                          ...                ...                   ...
# 1286975                     5500                  0                     0
# 556618                      4000                  5                     0
# 644359                         0                  3                     0
# 620607                      3500                  3                     0
# 1531412                     1000                  5                     0
#
#                 geo_country  days_played_in_month  virtual_currency_balance  \
# 2246682      United Kingdom                     0                      5580
# 6027                Nigeria                     1                       399
# 16340               Czechia                     3                     11354
# 2156777             Germany                     2                      6095
# 1528218               Chile                     0                     17720
# ...                     ...                   ...                       ...
# 1286975              Mexico                     0                       426
# 556618            Mauritius                     1                      3285
# 644359   Dominican Republic                     0                      5977
# 620607   Dominican Republic                     2                      3200
# 1531412              Russia                     0                      5984
#
#          target_max_day_played  mission_played  sum_ads  sum_purchases_real  \
# 2246682                      5               2       38                   0
# 6027                         4               6       14                   0
# 16340                       11               9       81                   0
# 2156777                      6               4       36                   0
# 1528218                      0              10       39                   0
# ...                        ...             ...      ...                 ...
# 1286975                      4               3        0                   0
# 556618                       1               5      174                   0
# 644359                       3               5      139                   0
# 620607                       2               6       24                   0
# 1531412                      3               5      130                   0
#
#          sum_purchases_virtual
# 2246682                  72000
# 6027                    172000
# 16340                    51500
# 2156777                 113000
# 1528218                   6000
# ...                        ...
# 1286975                 105000
# 556618                   75500
# 644359                   25500
# 620607                  123500
# 1531412                  53500
#
# [1598855 rows x 18 columns]

# %%
X = clean_data.drop(['target_max_day_played', 'geo_country'],axis=1)
y4 = clean_data['target_max_day_played']

X_train, X_test, y_train, y_test = train_test_split(X,y4)

numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train= X_train.select_dtypes(object)
categoricals_test= X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

X_train = numericals_train_standardized
X_test = numericals_test_standardized

LR = LinearRegression().fit(X_train,y_train)

score = LR.score(X_test, y_test)
score
# Out:
# 0.026581449732501983

# %%
model.fit(
    X_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, y_train), (X_test, y_test)], 
    verbose=True, 
    early_stopping_rounds = 40)
# Out:
# C:\Users\herat\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\herat\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:9.69904	validation_1-rmse:9.62875
# [1]	validation_0-rmse:9.39352	validation_1-rmse:9.32351
# [2]	validation_0-rmse:9.13850	validation_1-rmse:9.06837
# [3]	validation_0-rmse:8.91565	validation_1-rmse:8.85156
# [4]	validation_0-rmse:8.73793	validation_1-rmse:8.67548
# [5]	validation_0-rmse:8.58981	validation_1-rmse:8.52817
# [6]	validation_0-rmse:8.46661	validation_1-rmse:8.40628
# [7]	validation_0-rmse:8.36448	validation_1-rmse:8.30632
# [8]	validation_0-rmse:8.28046	validation_1-rmse:8.22355
# [9]	validation_0-rmse:8.21055	validation_1-rmse:8.15525
# [10]	validation_0-rmse:8.14764	validation_1-rmse:8.09650
# [11]	validation_0-rmse:8.09890	validation_1-rmse:8.04981
# [12]	validation_0-rmse:8.05253	validation_1-rmse:8.00320
# [13]	validation_0-rmse:8.01581	validation_1-rmse:7.97259
# [14]	validation_0-rmse:7.98790	validation_1-rmse:7.94609
# [15]	validation_0-rmse:7.95376	validation_1-rmse:7.91619
# [16]	validation_0-rmse:7.93060	validation_1-rmse:7.89889
# [17]	validation_0-rmse:7.91011	validation_1-rmse:7.88351
# [18]	validation_0-rmse:7.89594	validation_1-rmse:7.87065
# [19]	validation_0-rmse:7.88384	validation_1-rmse:7.86016
# [20]	validation_0-rmse:7.87224	validation_1-rmse:7.85074
# [21]	validation_0-rmse:7.86323	validation_1-rmse:7.84316
# [22]	validation_0-rmse:7.83949	validation_1-rmse:7.83005
# [23]	validation_0-rmse:7.82456	validation_1-rmse:7.82077
# [24]	validation_0-rmse:7.81459	validation_1-rmse:7.81536
# [25]	validation_0-rmse:7.80816	validation_1-rmse:7.81069
# [26]	validation_0-rmse:7.80278	validation_1-rmse:7.80638
# [27]	validation_0-rmse:7.79632	validation_1-rmse:7.80155
# [28]	validation_0-rmse:7.78860	validation_1-rmse:7.79827
# [170]	validation_0-rmse:7.36559	validation_1-rmse:7.53245
# [171]	validation_0-rmse:7.36268	validation_1-rmse:7.53057
# [172]	validation_0-rmse:7.35768	validation_1-rmse:7.52669
# [173]	validation_0-rmse:7.35650	validation_1-rmse:7.52581
# [174]	validation_0-rmse:7.35468	validation_1-rmse:7.52491
# [175]	validation_0-rmse:7.34783	validation_1-rmse:7.51990
# [176]	validation_0-rmse:7.34696	validation_1-rmse:7.51924
# [177]	validation_0-rmse:7.34438	validation_1-rmse:7.51782
# [178]	validation_0-rmse:7.34106	validation_1-rmse:7.51558
# [179]	validation_0-rmse:7.33826	validation_1-rmse:7.51325
# [180]	validation_0-rmse:7.33791	validation_1-rmse:7.51301
# [181]	validation_0-rmse:7.33392	validation_1-rmse:7.50929
# [182]	validation_0-rmse:7.33321	validation_1-rmse:7.50899
# [183]	validation_0-rmse:7.33066	validation_1-rmse:7.50701
# [184]	validation_0-rmse:7.33015	validation_1-rmse:7.50639
# [185]	validation_0-rmse:7.32593	validation_1-rmse:7.50299
# [186]	validation_0-rmse:7.31813	validation_1-rmse:7.49913
# [187]	validation_0-rmse:7.31567	validation_1-rmse:7.49737
# [188]	validation_0-rmse:7.31230	validation_1-rmse:7.49483
# [189]	validation_0-rmse:7.30842	validation_1-rmse:7.49227
# [190]	validation_0-rmse:7.30707	validation_1-rmse:7.49178
# [191]	validation_0-rmse:7.29711	validation_1-rmse:7.48466
# [192]	validation_0-rmse:7.29648	validation_1-rmse:7.48415
# [193]	validation_0-rmse:7.29176	validation_1-rmse:7.48273
# [194]	validation_0-rmse:7.28945	validation_1-rmse:7.48124
# [195]	validation_0-rmse:7.28597	validation_1-rmse:7.47859
# [196]	validation_0-rmse:7.28334	validation_1-rmse:7.47728
# [197]	validation_0-rmse:7.28063	validation_1-rmse:7.47508
# [198]	validation_0-rmse:7.27802	validation_1-rmse:7.47302
# [199]	validation_0-rmse:7.27551	validation_1-rmse:7.47161
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.8,
#              early_stopping_rounds=None, enable_categorical=False, eta=0.1,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.100000001, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=0.5,
#              missing=nan, monotone_constraints='()', n_estimators=200, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=42,
#              reg_alpha=0, ...)

# %%
from sklearn.feature_selection import RFE
rfe = RFE(LR, n_features_to_select = 5, verbose = False)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5, verbose=False)

# %%
df = pd.DataFrame(data = rfe.ranking_, columns=['Rank'])
df['Column_name'] = X.columns
df = df[df['Rank']==1]
df
# Out:
#     Rank              Column_name
# 4      1       day_auto_increment
# 7      1  total_purchases_virtual
# 10     1     days_played_in_month
# 12     1           mission_played
# 13     1                  sum_ads

# %% [markdown]
# # Web Scraping

# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import app

result = app(
    'com.halfbrick.jetpackjoyride',
    lang='en', # defaults to 'en'
    country='es' # defaults to 'us'
)

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.halfbrick.jetpackjoyride',
    lang='en', # defaults to 'en'
    country='es', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count= 5000#, # defaults to 100
    #filter_score_with=5 # defaults to None(means all score)
)

# %%
result
# Out:
# [{'reviewId': 'gp:AOqpTOE4zOrgn0-ASW5z-MIdHD5oy_942AAkZgCixnpZr0sgj86LJfcmZEpXsY8XOGE8ChZrEM9_HIUtn7cHpkU',
#   'userName': 'satya narayana',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjxGt6hGpq4H7u7tTShzMACZaJB4f_56Yf2cmD_',
#   'content': 'My favourite downloadef after years. Same fun everytime. Superb game.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 26, 9, 31, 54),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGBJ7Xd2zL0gV08VQnxxymsMHfWNgg2lJvpEKHZodq-GR7u86NsQICr2Gi5X-Lt7txw0yHEIcqJoGyq0go',
#   'userName': 'jay calonge',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhxPmowUKjS6yoNqV54KTRyTr88kfivy85aUNX2',
#   'content': 'This is my childhood game, fun and more, but ads ruined the game :(',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 26, 8, 7, 55),
#   'replyContent': "Hello, Thanks for your review. We've added advertising in order to allow us to continue to update the game while keeping it free to play for everyone. Making an in app purchase (such as the 10,000 coin pack) will disable advertising permanently. Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 26, 8, 9, 16)},
#  {'reviewId': 'gp:AOqpTOFvF9IV3g21xcflDmyfL605RovV9ZsNcSOrfPP5tsX8sFk981wc2j1bWw07jMk4v9K4p7Aw1liGhVhGcTo',
#   'userName': 'Adai Hernandez',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwHOMrqBhADWRhLDF6lFlOwcO_I35V0YKhBvNM=mo',
#   'content': 'Love it so fun so many thing to do and buy.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 26, 3, 27, 55),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFik1UDbTtKnjUwzFb5uPccd6cDozXso4vgAX_R5gE18lFwBixVRbUYrtWeVQjrE3syg5wk3nOSC6f-sXY',
#   'userName': 'William Jarrell',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgTpLO4IVXN2byg4KheSYM8T0qObE0e7wXQ2WJZMQ',
#   'content': 'Man I love the genocide route in this game lmao!!! In all seriousness this game has a lot of love and care put into it, played this when I was little... Great work!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 26, 2, 54, 44),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEQfuGum8YY6AjoT4d2FC35K5GHofaAINkxsx_xabKsoG6NxX07LygQsuLC6CYaOGXnhNGDPw28Wpfi0ds',
#   'userName': 'ghost fighter of the darkness',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GidqmhsrN5LC6fioIKOpsfKHD8OxkwHtsgcBKgm',
#   'content': 'Awesome just awesome nc job devs',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 26, 1, 54, 53),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHVo9AEm1jHoPespvk5PHMCm-zX5NVWFNNCPwFwLcyGrHe8_IWtVUn97v1epuuSLW0JFPdjvQKSxcjiIis',
#   'userName': 'arthur Millstein',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgyvEvi9NnniNNmzjBHK3oyPumn1EtTI33ZQBFy',
#   'content': 'it is really fun my baby cousin showed this game to me and I could not stop playing.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 25, 23, 2, 10),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFVfMy3Wq__qBaQLg7HBRsDC9H560YD8dLCk7q3nu1EzU6W02egYvmhZfGb6XStPPUkz9mrrtJ1DW4bQqs',
#   'userName': 'Rakesh123 Rakesh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzKoGfImeLTus8zf3mYbgB19ojCO_rNqw9-ApKD=mo',
#   'content': 'super game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 25, 21, 11, 11),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOF_p0PA2Y_2T1XWZcCrCMXPAu8dpQzNnr1S3DDar5nnNfFRZgs8HXiT7k_sWOi4CvYME8DDIQOcZgzp6I8',
#   'userName': 'Luke and Isaac N',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJy3uxOEvid-G32nAqmoPRTYm-DhcGEX73JAjQyz=mo',
#   'content': 'Childhood',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 25, 20, 32, 13),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFOdQJIkrHKU1llD9JBx0VXwARvN2nt_Kqw-5mgYIR4pHbhcQgFFjlvvP0JpanEqAgMgdFGvdJU6NbBJ90',
#   'userName': 'PPG Adventurer',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhkoK3s_9nriczJ3XHi_p_ROtNEwSkdzUyhJ3_FgQ',
#   'content': 'Legendary game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 25, 20, 23, 34),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGkihkHZxnkDBhG8nqkocHziKjwQbffaPIc2W91gjv91ptMbFk77A2c4O6tWduk_FqoL7KFXnD_4dBetyU',
#   'userName': 'CIY Gaming',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhDjEyWSqIMJZGgdk17aiTaktZtwNzGehYU1rIy',
#   'content': 'amazing game. all I have to say.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 25, 19, 49, 28),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOE_3EEPKurzquh-qf5dOWtQr4sMC-JEDvqN645S67mod0zrQTpDeJc0rwbJi7C5Q2_xfUnKfv4IMreS6-I',
#   'userName': 'Trayce Jarvey',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwb7Ga686haIt43kNBEG9v8LsBSeBtBbaDTnoLQVg=mo',
#   'content': "I used to play this when I was like 5 and I still play it till this day, in my honest opinion I really think this game is cool and it's fun to play.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 25, 19, 46),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEZrIvkgpx1lhaEcsuVj3ahP6XUWjGubHExEiWZ_Jl26btTH1FHQt0REgn3ljX8GCp8MYO66iudNoesIGU',
#   'userName': 'Owen Chang',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhKu_YNRgdAQeUOnXvRo4lwl8YBM3bZdmTZ0YgCUA',
#   'content': 'fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 25, 18, 43, 55),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEWmCrXmjwa0q9XaNwQkjJ0Lbdn3GWI5H0DMcivs3Qqalozp6c7qRKsPS7fJWgXP89OXczVFc084RLnUnE',
#   'userName': 'lukasraza 11',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjUE3sP1IKKdLDud-PV9anXht5uY-8ICM_CEnb6OA',
#   'content': 'Banger',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.63.1',
#   'at': datetime.datetime(2022, 5, 25, 16, 18, 49),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFzkVtCfBlLaUNbZg-BUfeh4m8CfBJ5kjz0upWXmNJ37-fDQruXssMAZJwyhMKBnCfopXnSG2yogw9YD4w',
#   'userName': 'Mark Barrett',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwIXSR5fJy0uOuSpHxH4UdT3sCh4khicSPd8kkL=mo',
#   'content': 'Back to it Boyz',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 25, 7, 30, 2),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFpq0ibO2UuGRm_FIfNKizRpgmztu78niNUEhXTfNtAET55Qgd3UKARO24ov--h1yX6K_yPIYT6zFdTeOw',
#   'userName': 'Adolfo Laguna III',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwu1jxrMLSfL2YOCyb4ji2CXyEwDiTIiI2Yp59C=mo',
#   'content': 'fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 25, 6, 37, 20),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOH5hZR8aCIj_7dB20vMPCpJA7ANeJILUqN2q4gycB_dqFWOGR-l5OpUw05K84ozCmMktxPP0_ocuj9AR5M',
#   'userName': 'Martin Medvec',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gil-FdwfpOAipJNx_E6362aAEnsBJLw4IxyBrSCWA',
#   'content': 'Few years ago I loved this game. I have returned to it to relive the fun again. Only that the ads gotten 10x worse. I wanted to get free SAM at the end of the run just to be met with message "no sponsored video available" which for some reason meant that I also couldn\'t use the SAM. And after using spin tokens a sponsored video suddenly became available and ad started playing. Of course it was for some reason bigger than my screen, so I couldn\'t see half of it and neither the close button.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 25, 6, 4, 38),
#   'replyContent': 'Hi, Just letting you know that we’re aware of the issue and our team is looking into a fix as we speak. Shouldn’t be too much longer so hang in there!',
#   'repliedAt': datetime.datetime(2022, 5, 26, 8, 10, 34)},
#  {'reviewId': 'gp:AOqpTOE_yq16SVjG2n-0Ay7WmYwCQrz-ijNmbtkoFTygNefJk_rPscMdDLm8iWz6w7W5pDndH5iQPDRGTJvVDdc',
#   'userName': 'Moozakkir Ugly',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwsL86UsvyrThxVrMaxZYInq62erb0sb8imSSEg=mo',
#   'content': 'Good game and all but i finished the prolouge in dan the man and didnt get the skin. That part is a 1 star. 1 day later-i just figured out how to get the nam the man character so the part where i coudnt get ot is gone so 100% 5 star',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 25, 0, 12, 30),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHTf58Dk-FwoYNmBYaRUZY2lAJLIOls5Wf83542rrpfSsisyttXWX5jEXsgaRr9LS04dS8yxsoGGWka9ng',
#   'userName': 'Chris Tatro',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJx2rcCp5u7Wo0kk02gGW93tBwuSKv_nnBjKO6tJjg=mo',
#   'content': "I've been playing for 9 years, the games changed so much. 10/10",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 24, 23, 4, 12),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGPwuCMOvl0nfR7bpNs4XV2IPjYnnr_w89GKTf5G1JPy2E0DGmBPvgJwzcGLj11JyVh8Bgy55xlv8J_0-E',
#   'userName': 'bjorn Verhoef',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjGVRxe8nIHZimz4x8TmurEeI702UQuryu6eqbSvQ',
#   'content': "Ik kan niet inloggen met mijn Google Play account en nu ben ik mijn voortgang kwijt.....     :'(",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 24, 21, 15, 36),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGjp3I5X5W1d1Audthy6cXAe9R-HrFyJv03LDnVA4LAohXETTZ8oRJhVsxE9TYENghynEOttiuYRYCypd0',
#   'userName': 'Tiwana lamb',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyFohweeZCKksl-PXxA6OaM8_UnfSc5fxRVMOJ6=mo',
#   'content': 'This game is good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 24, 20, 58, 52),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGWmUbw15Varx7UsczKIN9hOIvq9-fHIUEcEXT-e-gB8CtPuxHKj0TiJ5lyg9bWZ_ZmFgTIHD0vMF104VM',
#   'userName': 'farhan shaikh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyL2VQpYpgvcltN0ZWDzH_v32njcVvrVvSrDIVR=mo',
#   'content': 'Awesome 👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 24, 17, 55, 1),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGAVHXP-v2YMyQOSi017JFmoEYrPoHgwTECPgA74NNVuDwP84XGN_oUBlM6oQfaG94E9r8dhA9ICGwB4do',
#   'userName': 'jerry',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz3oyE3praUYBiSsm-p6D6tAqWFOcIrCz8AfmWx=mo',
#   'content': 'Definition of a game falling off🗿',
#   'score': 3,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 24, 9, 43, 18),
#   'replyContent': "Hi there, thanks for your feedback. We'd like to know how we can improve the game for you so we can earn a 5 star rating from you. Please send your feedback through to jetpacksupport@halfbrick.com and we'll pass it on to the team. Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 1, 33)},
#  {'reviewId': 'gp:AOqpTOEHfAkcuCB6W6texIX9cDv2IiAVs31rL72r94v1Z7xyxKrHIzq1U4_9hGI8EraJzXbCbaaIy_CGymFx50s',
#   'userName': 'Adithyan Adhi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyK1syn47ZJP-LG75CyHiGRQlyhJe6iePgS0zln=mo',
#   'content': 'Very very nice game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 24, 6, 39, 53),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHKy1WUQDhJwxmKw25Z2uZwnjw49EzdbMNn6OvGYJh_HEf6pvoigrnx9_BIRo_fDwrLrqVB3ds4v-ATi8o',
#   'userName': 'Amar Daniel Pulido',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GicSqvZHmqg0z4zx4kA9bpUxSdsjeG1CqxV-N9I',
#   'content': 'The perfect game that will always be remembered',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 24, 5, 53, 58),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFRcXRabWglUQzY6FskiC-WAf2jksl8IO7bvD-dwCQUSZLNh9AopBLjHQMSJ6CukoggQfah728ssOBUlwE',
#   'userName': 'elijah miller',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiG2Ze2jUifdH612HLUjaZs-d2FFxcMinFskS_y',
#   'content': 'Use too play this all the time glad to see its as i remember and more',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 23, 19, 26, 59),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHxssxOtO4_8eWh6Y_cSAh1HQTXOc8j2Dr4KNGSB9NnblwivX2qwdzBC9vgz5j5TKUXX8M_wnex27UPBWM',
#   'userName': 'Sam Frim',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwxDqSBOeMPj796jzu237ryA6mTVu7sZP4p4576=mo',
#   'content': '😍😍😍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 23, 17, 46, 24),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHmltqAoOwD5VU42ABzrb8axYLoHYSmcEOcto0ghxze2sucY1KhlwGGG1tQl5IJ0osY6dhFNJ6ZpzAGroU',
#   'userName': 'Koury Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzSteCI0EWBi0V8opdnOhjrkGpXBM5-u8iLYHyD=mo',
#   'content': 'Great GAME',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 23, 16, 18, 4),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEQhhHwzf_XaFs5hn69FhzQfcWpzhWR4bYr7uenJsgRBwjhPiLQKaKBNdoQIjpTOn7XDLO_y-GWqtgSeEA',
#   'userName': 'John Munns',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gho-kCmxWZrXiCL0WesRuXm7ZyDqUV_pkScB9W3Qw',
#   'content': "The account saving needs to be fixed. Jetpack said my gameplay was saved, but when I uninstalled the game and reinstalled it, I lost 30 levels of progress, losing 100k in money and over 100k in upgrades and items. This is not the first time it has happened. Jetpack clearly said 'Backup Active'. I enjoy playing the game, however the useless events are not entertaining and give the false illusion the game is being maintained and updated. Some new features would be greatly appreciated! & LESS ADS!",
#   'score': 3,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 23, 9, 52, 43),
#   'replyContent': 'Hi, sorry to hear you’re having issues with Jetpack Joyride but we’d be happy to look into this. Send an email to our support team at jetpacksupport@halfbrick.com and we will be able to look into it for you. Cheers!',
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 4, 33)},
#  {'reviewId': 'gp:AOqpTOEM8bTciPYUQMk_Kpi6EH-Wr0hd2_dwfFmpMMnniGjrAKDNZyOGikhc2fQN8eZg98mi8xjzgjGoGSIoE8c',
#   'userName': 'Abd Ur Rehman Rehman',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwobTDefbMZtsoO0gfr_AnjS0I6-1jWC0s_JkOr=mo',
#   'content': 'Fly like pro',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 23, 8, 38, 39),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFr8y1NUBSJpc9-isaxYU7sf7Ps5DhUy8snztOcZ8Em4Ncj6aS-nq_ROIdKaVwKO0xq122DKceBMZAnF9Y',
#   'userName': 'Tails The fox',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz7IkNyiR3zN9E-dntoGSVh5iglWtje_RKIbjoj=mo',
#   'content': 'This is the best game I played',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5,
',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 22, 12, 46, 54),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEAlPhYzzh9CvmyZ9l6XZHsyUW2lmEvu39zFYN85PA-jEdGR5W_dm7wzb4PiBnAYLmdE8EyHPhy-FWJ-yo',
#   'userName': 'Josue Pina',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwjTO0-6JqpWCo64dRgICxlxkpBRuNfpPnjoMOP=mo',
#   'content': 'I have 3 words,I LOVE IT,I havent played this game in years,I love the style of ot now,I was around 7 or 8 years old sence I last played this,keep up the good work!:D',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 22, 5, 6, 9),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOF99u-73dJTg8l_NTLpgEY6znmPA3yEGgyuLQU1gzabZH8TXEV4LeaeSiRmRynkpnciMVZmohrb4X9xvLE',
#   'userName': 'max',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiZF94SPt10l-T8Yt2CeUkAQ-6JyzDY0bF5aVuZ',
#   'content': "Played it as a kid. Loved it then and loved it now. If your a kid reading g this then get this app now. You'll love it.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 22, 3, 27, 53),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOF5VABjjIw1-l_feAfyZvcAVGBplQfEI1hTHE_-ld8NfU-M4zEZMuFCDAtk9SikKYvdFqvCOr7sXM6NjVY',
#   'userName': 'Mookies Romero',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJywA7KA1-Qw3O_Qsr8mXRJSxWdy9lCKuRrJuDH2=mo',
#   'content': 'I like to annoy my nobor',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.63.1',
#   'at': datetime.datetime(2022, 5, 22, 1, 7, 22),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHrHDpjFTU7SNqtT56NziVaJ1yEFF-bODg7ivshZF61iQQIrXbGB7qeB850QFs4unAmxEBONDCu4hEGreE',
#   'userName': 'Saudatu Adam Muhammad',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxmS5QaYpE8FIcGrdDYm9WJTkPan6TbIo3SUZBQ=mo',
#   'content': 'I lke the game👍😍😎👌😘💖💕💗👎👏👋💆😘:-P ✌😬👥👮💑👻👻💕👢👔💣💣💣💣💣💣💣💣💣💵💵💵💵💵💵💲💲💲💲💲💲💲💲💲💲💳💳💳💳',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 21, 21, 41, 26),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOE0VX6yJkfalhu2xabrHzSPFpmJTA659bdnrTS9DFVow1WZIRUKjKvLVbU7lQ8kjXUbLVxNahTBL52vz8Y',
#   'userName': 'Дмитрий Безрук',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhEeOPcHbp2MmGAZuc6wa7D7FNg_yxZ6-P4AR6H4Q',
#   'content': 'To match ads',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 21, 20, 25, 26),
#   'replyContent': "We see that you've given us one star - are you having any problems with the game? If you have any suggestions to help us improve, please let us know at jetpacksupport@halfbrick.com so we can get a five star rating from you! Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 15, 36)},
#  {'reviewId': 'gp:AOqpTOEY_mzOqSat5qKGjlvYfet8_PR09_4G2ZH3f7bEmyuLRe5hpMlrDrAUmesQuSLG82vf87OsXpo1jb78s_Q',
#   'userName': 'L V',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjuXDZjhblZ60bpjF4eBtfPUcdGeHlZ3FCEVRTCUA',
#   'content': 'Game needs a good cloud saving feature. How and when am I supposed to know whether my progress is secured to the cloud? This issue cost me progress multiple times.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 21, 19, 43, 21),
#   'replyContent': 'Hi, sorry to hear you’re having issues with Jetpack Joyride but we’d be happy to look into this. Send an email to our support team at jetpacksupport@halfbrick.com and we will be able to look into it for you. Cheers!',
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 16, 3)},
#  {'reviewId': 'gp:AOqpTOG-8o7644NcezaiHLlXGd7wpxR8BRMXH2tpDAp2JLTSwQss5mipyqTchUHAg3TbxIzVm1dOJftXtnVxFtE',
#   'userName': 'Ábel Bondor',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhU9Oj7t9GWGwyFB60SkD84eUoEj_-TgsE0oeSoHw',
#   'content': 'Best game.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 21, 19, 3, 9),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFZqSk-Qki3H7gpJTLWw77wEDAP7jGHWInx1CWvkME9mdYVCFX9RtmnHuKSTlPda87tma7BIRar_psy2qY',
#   'userName': 'Bear Veltrano',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJx4yTppMUHy_hrbRfE6kRDG7pdJ0zKYi0m4KrCG=mo',
#   'content': 'Just to classic to not like',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.57.1',
#   'at': datetime.datetime(2022, 5, 21, 17, 41, 19),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHgs6HgrjGjj5VHFX9h1P2ftjc6H8RTFlugoXtYYXwr4IHlQpIjiHcKuOVpZ_RPj3M4neZOkQ_JpxwJ-_Y',
#   'userName': 'Mellesa M',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgMQW1OMVLBYo8hV0TdrB36mRKSKV8eRO7eRRcAbw',
#   'content': 'Just runs slow at times',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.63.1',
#   'at': datetime.datetime(2022, 5, 21, 13, 46, 39),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOH_df4c28qLtGkvUWUSrzGleuaFJ4jR2557B75Y904HeAu-N802uTnwNIC32QYsg_d6vMjmOjM9xR9kWjM',
#   'userName': 'Beauty Ugah',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzfkSM2YWBEpBTeeMLMmWkcZImN48TEBFJTayal=mo',
#   'content': 'It is my first time playing it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 21, 11, 57, 49),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHTvUP9GMYDVsG8LI_ZJ_mI5X18ZCpZ-P8RYY-_dSaECn8u5wsIrfDkUZS3lMojFUlCqczZk9fHtF7GgKs',
#   'userName': 'NielTerrenceCalinawan Calinawan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjsZg1PbENVPsKbTpgaD42--JuB-5QpvlxJKtm1',
#   'content': 'Auegh Beach na peke ang dami mong tada isampal ko kaya ang suso ko sayong mukha Ahh!! ahh!! nag change ka tones 2 times a day and my nigra fall to my poossay ahhhhh ahhhhh 😩😤 💅 ang dami mong tadaaaa',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 21, 7, 8, 40),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHJHejp0YSphqL4nVPtUxJiETFcQpIEVyKlnP2OKZcXZYNCzZPw7NR4OIGeqDbt6nOc4UpPG-HRJTSMeA0',
#   'userName': 'y6912 y',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwnoSnPpAlke2AKSz0OdEVjtypUwLyFGa1TdzqA=mo',
#   'content': 'Super fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 21, 4, 37, 7),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHvzCXKlVd6oQG48uv63xTEwSy3ODjn-qYCqohZ3T1jRB24SbBNTWqKPFJAcfbSwYTmeUrWIf3s04KlRj0',
#   'userName': 'CT S',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhaLlT7P3inB2hW69OWCYJuPdRdS2ETtEBA24-4qg',
#   'content': 'Love the game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.64.4',
#   'at': datetime.datetime(2022, 5, 21, 1, 48, 34),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOE9uwS9BdVukhKV_9aKe-tZ4GCgdgUCOHQayuJlEzGSki1o-vn5QoRaeZ699lEngELqMHsTmjM7RhgXl-k',
#   'userName': 'beyblade burst',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhxAjFy5EvWdK2qnBIyNxmtoCtqytBVBsHOan_99g',
#   'content': 'Fun to play when board',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 20, 19, 44, 21),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGSHDC2uRdx9eJX6kE1fk4WyU_vJizez9ebYOEjR5u8nm4ll8vbZDYcww3DDPPlS0XSVSzacjpvNJ2ibas',
#   'userName': 'Pan Villanueva',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwqUPsuO50SFTalp0SRJ26E_22EoIYYuehTfNMb=mo',
#   'content': 'Gun=good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 17, 46, 45),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOF5uwhFKvWQbWHXWqmXlR66bEk7FcZvOcGyqCeWGbSA1M3tK9w2_akx9BTtWP9HDq2vsdizpsXKAhiXSDQ',
#   'userName': 'Yameen Jutt',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwRHZbSrwH24H2801GXz2gHRHKGRrk0aYfPtStm=mo',
#   'content': '500 💎',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 13, 53, 23),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHNbmqlZPCk77eFKOvrdz4iLVSnVULjnjEmqyQpb1cGOCPn5O4QeHs_DoFNE0ISbHs3xnQ4BSXkGZlrCJU',
#   'userName': 'Belinda J',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxBvmWwdB6YFNY6vJR5u_Vz2tNVegu5X4fh1CO7=mo',
#   'content': 'Just good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 12, 53, 55),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGZsRusZoKKtIB1Zm48fn1w8N9KCbtxmvkyx6PErMDh9f7xw7Y8VSWr0DlflFvH8R7UZd-3PIWz-CA6U6A',
#   'userName': 'Bloody Boy YT',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiB6-zmFnp5_ypNtDgJotK94BoMxkudVkyFpGXrmA',
#   'content': "It's the first game I have ever played in my life",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 11, 2, 40),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGgMIrEY6hGsiWAs4bqqKf93zOWWePlctDY5ngvM3MxiOP6tvp-60ebwzGKsk4PL8VLGMbpngTIJaXyzm0',
#   'userName': 'Ram Babu Rajput',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzNAF5Dnfj_5bQdCqKu7nyf8gv9ZKoRLM85yuo_=mo',
#   'content': 'Although I think this is a fabulous game it a very good time for me .',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 10, 23, 55),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEv6A5tJ8iNZm071EuYIT-YI-xtmtwMhw8pyCuBQQxHvXov8gfQvt5IA_Ef-MvM-vosjfM-KWZqonmVRxc',
#   'userName': 'Mayank Rajput',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg_U9f_JknIckdy1Zwn6j_te10AoUFLUPuXbAyl',
#   'content': 'This is a very good game for kids and adults also can play this game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 10, 22, 21),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGOq4CMmzS9kSVI4ZN-xhIlBC9fZdfdT8roWirOczj6lqvY6lM8nOXRwLSx-a1IJEappqygzELY5fzrKMI',
#   'userName': 'jason arias',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJw8vh4BqIWiBiv2NBRlnyTVasLBdU8fl-c_blu-=mo',
#   'content': 'I miss what it was. This game is a straight money grabber now n it really sucks. Adds every 10 seconds, need to buy everything. Honestly disgusting now and im deleting and wont be back',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 8, 50, 21),
#   'replyContent': "Hello - we're sorry to hear that you're not happy with Jetpack Joyride. Are you please able to share your feedback and suggestions on how we can improve the game for you in an email to jetpacksupport@halfbrick.com? Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 31, 55)},
#  {'reviewId': 'gp:AOqpTOEDfvSlbr7tQWDsVgsH089pstPcrgqbKm_C_jVAeL_7d1fsirrnToLedm1z7YB0ibHQWvNfdvn4ot3HBLU',
#   'userName': 'Krishna Singhal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwPSjZxbIz3s82BxRY4qRX0Zu_VFAHiH2krj8hW=mo',
#   'content': "It's just.. The best.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 8, 0, 32),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHO0hjSjtkZGhvhlZCo9LTNhFcP1HyCrDMYkGX4kWDXbmribIgYDFA3lb8kCd8lHvftOldWcmSWCdsSK3s',
#   'userName': 'Opheebop',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhX3ne26sIfzoGETeibAsBUYQlTajF_r_0RwqWUkA',
#   'content': 'Pretty good game I think it could add some things to make it better but its only my opinion',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.64.4',
#   'at': datetime.datetime(2022, 5, 20, 6, 0, 4),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOG9l39fwybxwvQVbe3SMGdr89QgtSV-yjVpu0Q7IjrcoQPKRb6S8kCaHeKVNnSQ8mqU0-d34GMQUrudroU',
#   'userName': 'SRIDHAR. R . R',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyqDj1rz5ZWxNOaZ_55vljlobzNnbE7mwqtvyoc=mo',
#   'content': 'Good service',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 20, 4, 38, 54),
#   'replyContent': "Hi there, thanks for your feedback. We'd like to know how we can improve the game for you so we can earn a 5 star rating from you. Please send your feedback through to jetpacksupport@halfbrick.com and we'll pass it on to the team. Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 32, 1)},
#  {'reviewId': 'gp:AOqpTOFCItQdenyrGoYiaupQ_0VegoQNJsmdMTc-gZxdDz71NhWKZyR6eXNm1MeVPoi-XXhWo1tZ5CKULOP2kSA',
#   'userName': 'Gamers Against Cardi B YT',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GicsMWrqHkabD3bKn_j0-1nz4eGkDAOoraZTsx8Ig',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 19, 22, 23, 6),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFVZdrUJ6clCRQe4IwHb_SXiQvB_0_0LQ4j-ipqCeO2PMz_h1V8vyi7SJ1HYQH6ggclcTBFgr4WxXg1gyU',
#   'userName': 'Jay Kumar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyULrlEFgvVS1YFvKBC3cVUYkbb5Qg7Kd0dUKE=mo',
#   'content': 'Best game😍😍',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 21, 53, 33),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEGNs_hFFH1HiumffcbRdcgIjbNim_XNTW8A9FWP_gQ-ztKejkNjfO_vilKqjruH1bFrsRmATa8rEmsSZs',
#   'userName': 'Amado Branas',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwUE9iSqUmP-9dpo1VJM9mMYjQmLYZcAUI4cixh=mo',
#   'content': 'I love this game, no comment',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 19, 21, 48, 10),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEOhZVtMVZhFW_MW6ZkIjnWA0Y5H_jViX-ErVEbR0Lv0qUAn4uHixWqC6TkwSOeXgYk21eEWi_0KmfRAuE',
#   'userName': 'Josh Carr',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gjrd23jlPcxffkx1tpzgDuGm63KnjlY2zwjuDaN',
#   'content': 'Played it as a little kid and now im an teenager i still like good game good designers keep up the work..',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.64.4',
#   'at': datetime.datetime(2022, 5, 19, 19, 38, 39),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOG88AgJbeEDe2YtpCbnqZeyKH95dUzcyuDjXaPuuwu230ZYZTgWH1K9W2T8v3dRlyuoZKF4Y-n9pYgcVSI',
#   'userName': 'ali rammal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjaphM8GkERY8o1YFIPk5iC0uG24za3voO0eOFM7A',
#   'content': 'Childhood game!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 19, 25, 53),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEwXhBMoBNdwUYm6-cJmmAlw65M_L4QZ9Vhwj0TwP0Wu95h1L4NclIn-6WQ6PaEBnRRGZmUMfOAPOrtKNw',
#   'userName': 'goose',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhJmLq-Cd3cUos_QBoWW-pgOuUWwFqehcZSZn57dw',
#   'content': 'still an amazing game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 19, 18, 52, 11),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFT3UK5jS8jCwHH21zQ-1rsmDMFWK37YPRqx5hIRIQrSIWzInD7g-bW0uFiNoYYsK0KzlJmJuLl_neLEYo',
#   'userName': 'Aaradhya Kaushik',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxmzUlP6Feaxk4jgafqutYRpr7mq83u6I2iIn4x=mo',
#   'content': 'Very nice game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 18, 35, 40),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFi2cbV8YjFpKBWqXV44a7RSz0-dmUMBUsuua04LEvXHREfVMW0nGgEFlrnZyXsemLNfpjNzsTEExh09_c',
#   'userName': 'ApexSkull',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh03J3jmh-qFmI9YHIUFxxJ7A7F7F3AXtK2FKcI',
#   'content': 'It hasnt changed much but is still fun',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 16, 11, 53),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFsMS7ArcQqSJaRl3YwYDw_n2ontoSKyCierWjOqiUKZjuF8yq27zDJJeYql-oiXLP99lqS6DR4MrObKeY',
#   'userName': 'N Preston',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwK4GOmiw37eiELon0MF6HPXYmzGCHL99XPDdIs=mo',
#   'content': "Really disappointed.. enjoyed playing this for years across two phones. Now I get a new high score for distance (12000), 100s of event tokens and about 4500 coins - crunch, the app crashes. Absolute deal-breaker as I've already contacted you about losing event progress like this.. glad it helps you improve things, not so glad that I lose awards each time I've come back to have a try and see if it's fixed. Had to uninstall unfortunately.",
#   'score': 2,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 12, 38, 10),
#   'replyContent': "Hello - we're sorry to hear that you're not happy with Jetpack Joyride. Are you please able to share your feedback and suggestions on how we can improve the game for you in an email to jetpacksupport@halfbrick.com? Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 36, 6)},
#  {'reviewId': 'gp:AOqpTOFCnsSsTy_nromhBexFJsU0pTMY212QiFTXK0w31g49QgI-0k7AuTIc_TUsi-vAijzcVHBEqw4W2gDqK8w',
#   'userName': 'Stik Baby',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJw9BF_tt8Bat-cZwfi-1Iys_YTdzOctblOa8w8D=mo',
#   'content': 'it cont werk😡',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 9, 10, 10),
#   'replyContent': "We see that you've given us one star - are you having any problems with the game? If you have any suggestions to help us improve, please let us know at jetpacksupport@halfbrick.com so we can get a five star rating from you! Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 36, 16)},
#  {'reviewId': 'gp:AOqpTOHLK4Ac6InJZXeDkMEnz2Ymmw0Ycare-b4b4S0C50pE8jsMVlyC4U6NUB0JHE-x584XVxIpDcaj2-XzXCk',
#   'userName': 'Akash Ackloo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxHgJEPMsLHo0wtesKL2r_pwaKZ5B7T_e8c3WPp=mo',
#   'content': 'Jetpack Joyride',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 8, 52, 58),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGQRyvziRbIPEjFAv0ZusnA6riRRtan_JER74FOAYzipDu43F9UKxn_ZnQzhlONTtzLnCPNNsJToXZLKdo',
#   'userName': 'Debanan Sinha',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzAd_16aAneMgBeG2dRE2ocnPL_oiOOrvPQMLXC=mo',
#   'content': 'Totally boat',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 6, 45, 52),
#   'replyContent': "We see that you've given us one star - are you having any problems with the game? If you have any suggestions to help us improve, please let us know at jetpacksupport@halfbrick.com so we can get a five star rating from you! Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 36, 19)},
#  {'reviewId': 'gp:AOqpTOEfWWR_2sAtL701702XKnAxURehNnLcoC1A5TNIE0Ts2lVqxitX-CuH2uhXz5oq_FdmoWhmOgYrtmpfBSw',
#   'userName': 'Skylos1312',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gik6uffDOXrZtcpqpgML_3AxgzHNrOctZ8poZjUtg',
#   'content': 'Nostalgia',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 3, 53, 9),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEXgvupyshNRFTDyFWz3tnte7RbYAbehKKBROj41q_CW9a8526FbR1BmN9-pXslGAUUQp2oEPgsX-6-9Fw',
#   'userName': 'Liliyana M',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghch8teUsPbjL6uzfT2UFoz2479vEa4_jHyjBna',
#   'content': 'It made me gay Slayyyyyy',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 19, 2, 26, 52),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOG2qxGH9Tm1Q0jDSXuvuwxoXqWlAKc7H8e1PdxZRpT1KWz8RQQpg4-tUhtmcwLNWFhnY_v9G4aEr0FLlN8',
#   'userName': 'Jecks Flax',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyibQAigpATuvb1me9csfOKiOMcDoG0PcZO_Gm9=mo',
#   'content': "It the same game I played as a kid but I'm not a kid anymore the game feels the same and that's why I don't like it its the same game",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.64.4',
#   'at': datetime.datetime(2022, 5, 19, 0, 55, 43),
#   'replyContent': "Hi there, thanks for your feedback. We'd like to know how we can improve the game for you so we can earn a 5 star rating from you. Please send your feedback through to jetpacksupport@halfbrick.com and we'll pass it on to the team. Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 37, 40)},
#  {'reviewId': 'gp:AOqpTOF3oy88z-62jt-sS43zFkfhCzTtTFlEshKsKDV70fqutU1cB6lmTtkpD2JSzU-ZCudS3aACiPOi0ONwcsQ',
#   'userName': 'Liam Durfey',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxTFp6VdtW3GN0BH8AxPTCbjc-3SrPCQX4Kwrg=mo',
#   'content': "Amazing! I don't need to say any more because really is nothing short of amazing.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 18, 21, 41, 15),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOF0IKU7ykd0LhZn6aFiTRpmh7REI5TcTTdwy3WT2Bx2Q2-s8u24yHpiUB3-hZv15vpDHhoIfudBPlpyvIw',
#   'userName': "James O'Connell",
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxcNmQGG6OI4gEd5IzABmB-rrEhTZz-odKMm-4X=mo',
#   'content': "Ch dad jjdsjrnfnxjdjvjcjf and I are going to be there at noon and I can come over tomorrow and see 🙈🙉 and then I will be there for you guys to come back 🔙 and get the same thing tomorrow morning workouts and rest of the week he will be there tomorrow morning 🌄 I will call 🤙 and I will be back in about a half hour energys like it's kinda funny 🤣 but I don't know if I have to go back to work tomorrow but we can talk about it later too but idk if you guys want to do it but that is good for hi",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 18, 19, 48, 2),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOG0f2HFDLlUTYMxbODteDe-B9Msj7SRw6GJl94LIjldd542KVK6A1T-Sucb_wsn3LTL54ECENrkSZ9XRg8',
#   'userName': 'Anjali Sujan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh5pzJLfXBRtNVZ7f7MzWZ2NGpTLHUHLw2ED4YX-A',
#   'content': 'Incredible! These app updates just made this game awesome. It was my childhood favorite 😁',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 18, 17, 13, 8),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGqtxyz1IM3bsoQU-TXMevCF3qUkv6vtLxH6g5rXIdNHYcyx6qdcTuNT8dxaNEF04wa2IpoVZVrY6gHnQo',
#   'userName': 'Zayon!',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjkyNna6qjPcBFalOtECU48K99_foy3NGUydPXm',
#   'content': 'Pure nostalgia but microtransactions be ruinin it',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.64.4',
#   'at': datetime.datetime(2022, 5, 18, 15, 26, 25),
#   'replyContent': "Hello - we're sorry to hear that you're not happy with Jetpack Joyride. Are you please able to share your feedback and suggestions on how we can improve the game for you in an email to jetpacksupport@halfbrick.com? Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 41, 44)},
#  {'reviewId': 'gp:AOqpTOHBXA99cJ-DpmgKWU2xrlUmUUMZfBrXA1Lif9EtJJzCeMXDIiFx5cuAMBZbCf3hQWggZtU94FLGM0mHl5g',
#   'userName': 'Randy Brandstatt',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjzwtbLuPJH3ZWPbEYJT12euLMJx7mip4236wNEfQ',
#   'content': 'I love this game! Probably the ONE game I have played for more than a year!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 18, 12, 44, 9),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGYQYnPH2sJk4WXz2qDZhpWmDK_bjWjcF_dPFiwcIsZxeTyVvBnwuR5o6DA-miOsnPD61V-D-4mxAROD3A',
#   'userName': 'William Gosden',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwreI0HXUB2gImZjuOyyijzkv9bPcZ6IfHzD4Zg=mo',
#   'content': 'I was leve 200 and then today i got on and i was reset',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 18, 8, 38, 8),
#   'replyContent': 'Hi, sorry to hear you’re having issues with Jetpack Joyride but we’d be happy to look into this. Send an email to our support team at jetpacksupport@halfbrick.com and we will be able to look into it for you. Cheers!',
#   'repliedAt': datetime.datetime(2022, 5, 25, 6, 41, 56)},
#  {'reviewId': 'gp:AOqpTOGK7HNctbM1XpZtXSh4vCBhC4ABYseAjzfyNWtYHLolLAbx37XVvCQX2FttH06RmH9XlE_mO-dOpdXLkMY',
#   'userName': 'Matthew On-Point',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgtbDhqpZ57Il8Qz1ni6UjP6DLF4hy1rxNdh_jrPA',
#   'content': 'Great game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.65.1',
#   'at': datetime.datetime(2022, 5, 18, 6, 44, 36),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFoxwSwoaepelHEuj-PAsHnvCFjGQEiMYXZdRctlVabwmeIdCET-I9nOVAINhw-ik9Kzil1VxEDcIPwiV4',
#   'userName': 'Andrey Perez',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjgSpx91sV4sKEUU1iarjTkMha3sM0S3dtUFB6lMQ',
#   'content': 'Lo mismo',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.56.1',
#   'at': datetime.datetime(2022, 5, 18, 5, 7, 4),
#   'replyContent': "We see that you've given us one star - are you having any problems with the game? If you have any suggestions to help us improve, please let us know at jetpacksupport@halfbrick.com so we can get a five star rating from you! Thanks!",
#   'repliedAt': datetime.datetime(2022, 5, 18, 5, 37, 51)},
#  {'reviewId': 'gp:AOqpTOE1NhwTDT0QNMCDCS7Ars25z0sgs_vXbZTkuQqtOLxgQs239HxaFud0s4BvLpvLOcoKuYcjVP9XljrN0uc',
#   'userName': 'Becky Torres',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhLtS9_FQaKNUYZ3hVlb89sicO39JFx7_8fjjSlaQ',
#   'content': 'I have I have a question for Halfbrick Studios why does Jetpack Joyride is an endless Runner?',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.64.4',
#   'at': datetime.datetime(2022, 5, 18, 3, 55, 18),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGpko3n8ce08P7hGm89kPHo7BeSLqGcTJYuQnooorbsyENKU9j7YN_5YD1zjsOLv5BXzeNUjnDtw8ueN9Q',
#   'userName': 'Luis Fernando',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhH3e5pE4ZaJYyQPq8xsVupvDSXF3pvbPG1vu6f',
#   'content': 'Why pay for features such as a third item when they could have been grindible',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.64.4',
#   'at': datetime.datetime(2022, 5, 18, 3, 52, 45),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEZSHv3GHzMhYHnSsRSoMSv2wWuRMTrf09dX3ufxkfhmwaFWhGYt7yldIxNHifE6je-F-9umDMwwXc_Flc',
#   'userName': 'Ms Maleha Aktar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxIQ-0XoATfulIIugVU1W3bpzwuiE4n1P0o-dec=mo',
#   'content': '😈😈☠️😈👽',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 17, 17, 34, 47),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEyDY4wIlD_9D5HyPM7TSLWzxVxkPnBcePGXOfP9mZ-EwPu56eWpnr0TWCKYcQnBMtvEosp4IGn_Dz8oxc',
#   'userName': 'Frankie Barnes',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxkeqkgN_fXCft7QW6x0GoFfRtWHDnErLcpLnEn=mo',
#   'content': "I remember when I wost to play this game I stop I stop playing when the ad's ruined it",
#   'score': 4,
#   'thumbsUpCount': 0,
# ...
#   'userName': 'Alex Forbes',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjoBARm7gNxoMl5hZyrkrn3pQFJxjImGsEjjXoy',
#   'content': "One of the old school games, but the developers have destroyed this game by taking the same direction as all other mobile games, every time you die you're forced to watch more adds. Please remove these without trying to squeeze money out of me. This game is one of the classic old school games but since adds have been installed this games value has dramatically dropped.",
#   'score': 2,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 2, 7, 6, 2),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFCCO_hmuPW9xUfFQIXRDzStWEZLVLutUPWQDBnZKzU5wpTVJ9RJzhEEuKKyV6gOTopkpFkuxHMTujLDxw',
#   'userName': 'Blue. XML',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gid0bRelY4wp0qWA0-zBYxRuz0X9tFsm081IjQX6w',
#   'content': 'I use to play this alot as a kid and I loved it besides that I still think this game is fun to play.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 4, 2, 6, 56, 58),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGlCppmirLv4rLm6KUptJ1m4WzbzpbYKqF33rzZ8mi7-EVyZ7VseelCCDO9ux39j9PLH1Pg1-pi0MNQba4',
#   'userName': 'Just adulting:',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh_QH9rapE3ejFLsh24zQhtZYN454fTMjBtP0r4gg',
#   'content': "I used to play this until early 2010-ish with my late brother. We used to compete to see who could reach a new milestone, who could get a new achievement, etc. But now it's not the same. The S.A.M machine broke the game. What's the fun if you can get everything so easily? What's the point of this game anymore?",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 4, 2, 6, 43, 13),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGD44OnNEfgXLiDRup-jCSwXMUfStSTuvsUEiLSW2SnBn-pEcFQ_oHPlKVo-4AzahZ0CqaX2U2Q7LwuXxA',
#   'userName': 'Barry White',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhXRYcd6sO3CaQ8QwMbQMjTSEqeUrXZ9BJWqOT38g',
#   'content': "It won't let me play it keeps telling me to update the game when it just updated",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 2, 4, 55, 26),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGr_vER2D34zaA56Ky7w1kZT6_hGmpxmshN3g0HXmXp1tedy5DvT-ueuuJ4B2P9sgvKKYwrcpIqS_Ujs6M',
#   'userName': 'marcellus ehlinger',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzlPhbI8yQyk_6W1M5lScR1NBtw77VX6mgpJRmv=mo',
#   'content': "For how long this game been out im serprised this game isn't dead. But thats what great about this game, proving to people this game can't die.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 2, 1, 59, 11),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEBIOTrQA0KeAoiMd5-m1qNV7EXprqFB6oa6lxtFZhjEEBc-l-HhcOMNSwTNrBXApzeQ_Xjwbn17_ew2U4',
#   'userName': 'Stank Armpit',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg-bGyhdMrXNiuTQHWGYDaGpvSGEruBB73wgMpk',
#   'content': 'Made me 🤠',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.60.1',
#   'at': datetime.datetime(2022, 4, 1, 22, 2, 50),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEUzYb1CaFV9g32zdXUUdRMBzWDIRU1vVTSeYlKFTj4g3aHEefsDaW4V8mJ1g5RQ-RcTqgnwOn1dAITgNk',
#   'userName': 'Ryan Smrz',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhZOxl-1mY1k0TPG5jE7N4ZPBsXEWgAkOsVhYiRwXk',
#   'content': 'So cool you get free money and its not a dice game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.47.1',
#   'at': datetime.datetime(2022, 4, 1, 20, 52, 28),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGh8IqfBzgEz-ETCISO9XRbIxMlOuM4l4oL-gxmTqrZlZRLSN30bpLOCUAQrdsvMMPApV5pN0CCtNpkgfw',
#   'userName': 'Diff Skyhighatry',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjZE1zrvaAWFu9Gz2KyXuuOOBldRDbRYvfMlPVEsA',
#   'content': 'Loading screen stopped, so uninstalled game (done this loads before without any issue)relying on the cloud backup storage but backup storage failing so lost years of gameplay, paid items plus loads of exclusive items from events. 1 star until issue is rectified',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.61.1',
#   'at': datetime.datetime(2022, 4, 1, 19, 21, 37),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOF1Sb_wTIbqDv2SYAYf-t3fdewSTaBcwymyKdEqykliYqzu_2z5EZ-P0mvyqZ9VQu-9EQmjTMH-d-ViJ6w',
#   'userName': 'Finn',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gibyoc_6rqwz0Qs0oVrdUeAwa9AHNI3Du7qfu1fYg',
#   'content': 'Good game but ever since the update, I can\'t play. The message "To continue playing, please download the latest version!" Keeps popping up. I uninstalled, restarted my phone, and closed the app but nothing works.',
#   'score': 4,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 1, 17, 16, 16),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGS0dtE67V2PJJ_YmYoKUU2IbDEtapcOLbdHLQmU7i6mZIy7ycfHE5FfK8AeuUFFoXS_yR-qes5Du7es4g',
#   'userName': 'Baydenator',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjZwI_tZFoAWyy_iX1F-fF_OFkOVgLqcZKaBSvC',
#   'content': 'Soundtrack slaps',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 1, 16, 37, 50),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHuNidDMVLJjWTnsoRtfqMMdq3ACFKS3BrupUhPKGBfSSIsrHh3c1xN-wJiYxJ1xBlmejRCerdyORLChX0',
#   'userName': 'low gaming',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjHOOX7rzayKKc2VtIhoZwIhZTkRBj6wNU492m7',
#   'content': 'Good game, I have been playing since I was a kid and still enjoy the game with some many jetpacks to choose from and other cosmetics. The only tiny thing for them to fix would be the ads but, most games have lots of annoying ads so still, I give a 5 out of 5.',
#   'score': 5,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 1, 16, 29, 32),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEO7NlAa8jP1LjYmiyi7ZD4YyjSjqoFRzFjYx7IvU5HHAvYqgdA04NVkM5Yp7Fxy8y-ypGC4q8ekZvkzBs',
#   'userName': 'Malti Rani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiJ7rrPmZmE-Mha_3ozWybTSjb1XBUwo-iZBYKO',
#   'content': 'Op',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 4, 1, 15, 35, 51),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEvSzilXK65gMTuOgqxV_Doq1haSk0lGtXtc3deNSlO7Xl_ESsKe12jzX2zMfyc5Wc0gOfOM8cCUFwJMTQ',
#   'userName': 'Jesse Ong',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz9Pe4bJK_wM8XJ8jRSTSAMuxETtissE6E8NTrc=mo',
#   'content': 'Gud classic but can get dull',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.1',
#   'at': datetime.datetime(2022, 4, 1, 15, 16, 29),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGYnuOTioq9tVubAznrJZnIwcSGHiG0xZRFxdmlM9nEs1Yp6xcF7rvh2xTE4Wtel3HLgaaPLHGMWgf94ls',
#   'userName': 'Angela Dorian',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxh-6cxG1pz2uSiKHLU2SAcpXYHyxk5B0c2b42c=mo',
#   'content': 'Its AMAZING just download and see',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 1, 13, 26, 47),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFgrsDFzVKFE75C70ytN5OT2Uu7z9s9qfwB-ePt49T27AGznGN0maoj-PX4b4C-QfVfHEIfdWeIvIOjxaI',
#   'userName': '23 Nisa Gupta',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJymkzIKVdPy7haFcN3UstQcBYSTV044yFEuY_wHWw=mo',
#   'content': '🥶🥶🥶',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 4, 1, 11, 5, 22),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHSOiwNJyqdOweiJYHx0YjNWoRt6NhSiq5bHuRaB7uZ88X_GrTOeEhvIbkaYPwWZPBaoJQ3-uHkf14F5-A',
#   'userName': 'Harley Emily',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gizx7oUbzAzGkSljH29yMqrJRs_4cbvlNhf5xi0Tg',
#   'content': 'nice.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 1, 9, 27, 12),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOH-mHaI_G0QsW5-ZkGItVrihyDvBkpiG_cMx7qrSoT1NpgyTNTEndzD_QVFgI3BLal3lvT2DuHvKVnIh0U',
#   'userName': 'Andrew Mele-Smith',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiRRhrByFLD0pFCuYNa_VSkYSdzjYssmPznXOPajg',
#   'content': 'the best game in the world and the music is so good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.1',
#   'at': datetime.datetime(2022, 4, 1, 7, 4, 42),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHkZNlGF2sWpyoiF7Jj6Vz-ZMd6jpQjnxHopQsqYxGPJ6Bxyg6COdW8HcUyUQWU_mYNH9H-E7HRXD8c8z8',
#   'userName': 'Me La suda',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiW01b4S8hIQklACJz5-aQ8HUdX36Ab3LnjdzA5',
#   'content': 'this game made my childhood :D',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 4, 1, 6, 55, 12),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFGwzZfPu_IevF7kjLAh_tXgPasE8HCMPdopoulSOnTHVWAFmQ9K3SCdIMUlkMRUS0Dl9oq5wY1uJtoaIw',
#   'userName': 'Egg with legs',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjpyVClWQHSExxkK_EBqL5-Y2LwbXGxbuwTGe_U',
#   'content': 'I really like this game,only with a single complaint,i updated it and it says it still needs to be updated.But 5 stars!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 1, 4, 28, 54),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOGxatPL9atZDI7-pEVDREZEkSpKHK_VT7yRn4UpXyVbsw3nohj3zyTW_KQiydkbDlmbE-JLc0Y_kqH7SG8',
#   'userName': 'NOOB MASTER',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwL99HTshSLAl33iBiUZtnrbjLRKxL65KSLRI5B=mo',
#   'content': "Really fun game i used to play it when I was younger than there wasn't much but now there more things and activities you can do much better and funner game",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 4, 1, 0, 28, 40),
#   'replyContent': "Hi, Thank you for your lovely feedback :) If you've got any additional suggestions for the game, please feel free to send them to jetpacksupport@halfbrick.com. Thanks!",
#   'repliedAt': datetime.datetime(2022, 4, 1, 4, 22, 35)},
#  {'reviewId': 'gp:AOqpTOFAo5l4seMDhtT5tdZ363ZaFMKPVlIytxwz9rfleH_VouwQ0Z78kSsgUNzyEpB5YH2NLUj5q4zDFVd-7Hs',
#   'userName': 'ahmed merheb',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJy9PdlLz5T5Gcpva5BxZo1G8gThXHvlA22DQcgJ=mo',
#   'content': 'Pretty cool',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 3, 31, 23, 3, 16),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFidU8hEgY6HE0klcsGh8DttwrpGB83Ul4dNV71V-KxNvDGx0JGC89TRM7SgbzskLJUT24WQRj26lBlwo0',
#   'userName': 'Barry thegameralt',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJysR991zE8Wb_WMok5v28-IVmGL74OvTYDmCYV2=mo',
#   'content': 'My childhood',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 3, 31, 22, 17, 37),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOG6J1sC9ChCn3QPO9uE7OV1sxWQlGcXsYNReqekrcjblGl05cF288CDKIHSHoIY4RcIc1zUQ0_OnhvjAaU',
#   'userName': 'Noob Ryan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwSMHUKs-pcVekqpCQ66tm8jnlTFOYsK7y8heuN=mo',
#   'content': "Its a really good game to play on the go as you don't need WiFi ☺️",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.1',
#   'at': datetime.datetime(2022, 3, 31, 22, 14, 38),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOG1e5GH104mhS5HEE9-LIMf7JegPe_fJszQczY7QvWkljUPnuMn5beoyQwdLWDrdfRcwvWA8bAanQKs3z8',
#   'userName': 'Hypercube34',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi7aNGoGHpVP5kjwMSZdfQYLu2kNm10rfDzq0M',
#   'content': 'Nostalgic, exited to try number 2',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 3, 31, 19, 42, 48),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEfnaryaAdZykRqWzFCJGk6-FszheRo-E8BPGKFvfIRfGT7bG9O2DkFTDWt46Oz71jA4MTSy9v5SrMv4cQ',
#   'userName': 'Marco Polo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgkMXxEUurkgb-TC72AoMRBrya92d3fcxFZ1gxa',
#   'content': 'Ads',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 31, 19, 0, 16),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOH0PPazbgVij_uZd7V9_CfvtrwVbgNLq2Oj2g4zBomemzjGuVLFAAHkytGOQKHUnvNpeiMV_Rr2DObEqg4',
#   'userName': 'Aiden Foxie',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyV2VNPjaRPHN0Vl6GWhE7DOI0xSzr6hxL7ePvO=mo',
#   'content': 'This game is very great, make it extra fun, use lucky patcher',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 31, 18, 36, 22),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHJOiJicI4uWt0gXMWmAnrFK1ddh8ESpMqxH6R0o-_6fmLB5zfUjkYpwBhHQbCi6QIKi78dJTeQ3yqDaw0',
#   'userName': 'Rajendra Patil',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxqq_UgYmbJfNiPhJn0qCqEzGaDtyMErbDM7DPv=mo',
#   'content': '👌👍👌👍🎉😄❤️💗💞🇮🇳🇮🇳😀😃🤡😎😎❤️❤️❤️❤️💋💯💋💯💯💯💯💯💯💖💝💘💖💖💝💘💋💋💋💋💋',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 31, 18, 14, 45),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEJha4uPYBND4kw8pXaXhIy0ln7XYo4PfcLBwAyb00wjK481Fu_J2IhqURhKVtaVYiWouo7gC7FRruN8Ds',
#   'userName': 'Kayden Curtiss',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhKZ8yyPB95HDW1RHHuqJK1gz5RDxYxE1w5-v_V',
#   'content': 'Fun game. Played it since I was a kid.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.1',
#   'at': datetime.datetime(2022, 3, 31, 16, 56, 55),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOHM5YxaZGHvpkRJ7AOwgs1bzjeouuR9zCVP7XSes57AzeYlDrMXX4TC7VyFKJT0i-fTwt9LuMjYvQR2tNI',
#   'userName': 'Alex Anderson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyhIxbAKRHy9CZTCE9szKhyHpInln3aDSoU-0jz=mo',
#   'content': "It's so fun and nostalgic",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 31, 16, 8, 54),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFvRYtd3hb4KFmeveM-O3tnyjFoZDRJFShISqaDCjUWKJkI1ceygLO05MMNJd1vUauBzhc_1S3F-7KaPZs',
#   'userName': 'Peepop625',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgBfkU1WrL9Fd-gMT9BZ4301GYt4_B7TeYbyNeb',
#   'content': 'Is cool',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.1',
#   'at': datetime.datetime(2022, 3, 31, 16, 2, 1),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOEeH74O1t8Fyd6dyS0JBdHoxEROL7v3UDvkek7S2DSoRkLZXvznXdyOjgBo-LkIjoaJjcM2bH3SSo36Yfs',
#   'userName': 'N1S Subscribe',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjgQpa0ogkSYvnbHDEaYoIfFeb18YcCvRA6Efus8A',
#   'content': 'Yes sirrrrrrrrr',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.62.2',
#   'at': datetime.datetime(2022, 3, 31, 15, 26, 32),
#   'replyContent': None,
#   'repliedAt': None},
#  ...]

# %%
scores = []

for i in range(len(result)):
    scores.append(result[i]['score'])

# %%
dates = []

for i in range(len(result)):
    dates.append(result[i]['at'])

# %%
reviews = pd.DataFrame(dates, scores).reset_index()

# %%
reviews.columns = ['score', 'date']

# %%
reviews['month'] = pd.DatetimeIndex(reviews['date']).month

# %%
reviews.dtypes
# Out:
# score             int64
# date     datetime64[ns]
# month             int64
# dtype: object

# %%
reviews.month.value_counts()
# Out:
# 3     744
# 4     712
# 7     450
# 10    406
# 2     387
# 9     387
# 6     356
# 8     352
# 11    332
# 1     306
# 12    291
# 5     277
# Name: month, dtype: int64

# %%
reviews['year'] = pd.DatetimeIndex(reviews['date']).year

# %%
reviews.year.value_counts()
# Out:
# 2021    2574
# 2022    2426
# Name: year, dtype: int64

# %%
# %store reviews
# Out:
# Stored 'reviews' (DataFrame)

# %%
reviews
# Out:
#       score                date  month  year
# 0         5 2022-05-26 09:31:54      5  2022
# 1         1 2022-05-26 08:07:55      5  2022
# 2         5 2022-05-26 03:27:55      5  2022
# 3         5 2022-05-26 02:54:44      5  2022
# 4         5 2022-05-26 01:54:53      5  2022
# ...     ...                 ...    ...   ...
# 4995      3 2021-06-12 17:09:41      6  2021
# 4996      5 2021-06-12 15:23:00      6  2021
# 4997      5 2021-06-12 13:21:16      6  2021
# 4998      3 2021-06-12 12:52:51      6  2021
# 4999      5 2021-06-12 11:12:17      6  2021
#
# [5000 rows x 4 columns]

# %%
reviews.to_csv('../project_data/reviews.csv')
